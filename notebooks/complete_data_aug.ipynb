# %% [markdown]
# ## 원본 데이터셋을 이용해서 수도라벨링을 시도해보자
# - https://www.kaggle.com/maxjon/complete-tweet-sentiment-extraction-data
#
# 1. 분류 모델을 학습해서(81%) -> 감정이 태깅 되지 않은 약 8000건의 unseen 데이터에 태깅
#     - pseudo_senti.csv (senti_cls/pseudo_labeling.py)
# 2. test.csv에 대해서 selected_text를 태깅
#     - LB 0.715 나오는 모델로 태깅
#     - pseudo_selected.csv (senti_ext/pseudo_labeling.py)
# 3. 혹은 test.csv + pseudo_senti.csv에 대해서 selected_text를 태깅
#     - LB 0.715 나오는 모델로 태깅
#     - pseudo_selected.csv (senti_ext/pseudo_labeling.py)

# %%
INPUT_BASE = '/home/jeinsong/senti_ext/dataset'

# %%
import os
import re
import time
import random
import datetime

import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from textblob import TextBlob

sns.set()

# %%
train_data = pd.read_csv(os.path.join('/DATA/image-search/kgg/input', 'train.csv'))
train_data['text'] = train_data.apply(lambda row: str(row.text).strip(), axis=1)
train_data['selected_text'] = train_data.apply(lambda row: str(row.selected_text).strip(), axis=1)

# %%
train_data
# Out:
#            textID                                               text  \
# 0      cb774db0d1                I`d have responded, if I were going
# 1      549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2      088c60f138                          my boss is bullying me...
# 3      9642c003ef                     what interview! leave me alone
# 4      358bd9e861  Sons of ****, why couldn`t they put them on th...
# ...           ...                                                ...
# 27476  4eac33d1c0  wish we could come see u on Denver  husband lo...
# 27477  4f4c4fc327  I`ve wondered about rake to.  The client has m...
# 27478  f67aae2310  Yay good for both of you. Enjoy the break - yo...
# 27479  ed167662a5                         But it was worth it  ****.
# 27480  6f7127d9d7  All this flirting going on - The ATG smiles. Y...
#
#                                            selected_text sentiment
# 0                    I`d have responded, if I were going   neutral
# 1                                               Sooo SAD  negative
# 2                                            bullying me  negative
# 3                                         leave me alone  negative
# 4                                          Sons of ****,  negative
# ...                                                  ...       ...
# 27476                                             d lost  negative
# 27477                                      , don`t force  negative
# 27478                          Yay good for both of you.  positive
# 27479                         But it was worth it  ****.  positive
# 27480  All this flirting going on - The ATG smiles. Y...   neutral
#
# [27481 rows x 4 columns]

# %%
test_data = pd.read_csv(os.path.join('/DATA/image-search/kgg/input', 'test.csv'))
test_data['text'] = test_data.apply(lambda row: str(row.text).strip(), axis=1)

# %%
test_data
# Out:
#           textID                                               text sentiment
# 0     f87dea47db  Last session of the day  http://twitpic.com/67ezh   neutral
# 1     96d74cb729  Shanghai is also really exciting (precisely --...  positive
# 2     eee518ae67  Recession hit Veronique Branquinho, she has to...  negative
# 3     01082688c6                                        happy bday!  positive
# 4     33987a8ee5             http://twitpic.com/4w75p - I like it!!  positive
# ...          ...                                                ...       ...
# 3529  e5f0e6ef4b  its at 3 am, im very tired but i can`t sleep  ...  negative
# 3530  416863ce47  All alone in this old house again.  Thanks for...  positive
# 3531  6332da480c  I know what you mean. My little dog is sinking...  negative
# 3532  df1baec676  _sutra what is your next youtube video gonna b...  positive
# 3533  469e15c5a8  http://twitpic.com/4woj2 - omgssh  ang cute ng...  positive
#
# [3534 rows x 3 columns]

# %%
test_data.sentiment.value_counts()
# Out:
# neutral     1430
# positive    1103
# negative    1001
# Name: sentiment, dtype: int64

# %% [markdown]
# ## 원본 데이터

# %%
orig_data = pd.read_csv(os.path.join(INPUT_BASE, 'tweet_dataset.csv'))
orig_data['text'] = orig_data.apply(lambda row: str(row.text).strip(), axis=1)
orig_data['selected_text'] = orig_data.apply(lambda row: str(row.selected_text).strip(), axis=1)

# %%
len(orig_data.text.unique())
# Out:
# 39502

# %%
orig_data
# Out:
#            textID   sentiment         author  \
# 0      1956967341       empty     xoshayzers
# 1      1956967666     sadness      wannamama
# 2      1956967696     sadness      coolfunky
# 3      1956967789  enthusiasm    czareaquino
# 4      1956968416     neutral      xkilljoyx
# ...           ...         ...            ...
# 39995  1753918954     neutral  showMe_Heaven
# 39996  1753919001        love       drapeaux
# 39997  1753919005        love       JenniRox
# 39998  1753919043   happiness       ipdaman1
# 39999  1753919049        love    Alpharalpha
#
#                                                     text  \
# 0      i know  i was listenin to bad habit earlier an...
# 1      Layin n bed with a headache  ughhhh...waitin o...
# 2                    Funeral ceremony...gloomy friday...
# 3                   wants to hang out with friends SOON!
# 4      We want to trade with someone who has Houston ...
# ...                                                  ...
# 39995                                                nan
# 39996                     Happy Mothers Day  All my love
# 39997  Happy Mother`s Day to all the mommies out ther...
# 39998  WASSUP BEAUTIFUL!!! FOLLOW ME!!  PEEP OUT MY N...
# 39999  bullet train from tokyo    the gf and i have b...
#
#                                                 old_text       aux_id  \
# 0      @tiffanylue i know  i was listenin to bad habi...  p1000000000
# 1      Layin n bed with a headache  ughhhh...waitin o...   c811396dc2
# 2                    Funeral ceremony...gloomy friday...   9063631ab1
# 3                   wants to hang out with friends SOON!   2a815f151d
# 4      @dannycastillo We want to trade with someone w...   82565a56d3
# ...                                                  ...          ...
# 39995                                   @JohnLloydTaylor  p1000008985
# 39996                     Happy Mothers Day  All my love   0b62ea4f2d
# 39997  Happy Mother's Day to all the mommies out ther...   1adaa3519d
# 39998  @niariley WASSUP BEAUTIFUL!!! FOLLOW ME!!  PEE...   d63253be9a
# 39999  @mopedronin bullet train from tokyo    the gf ...   879f64f30d
#
#       new_sentiment                                      selected_text
# 0               NaN                                                nan
# 1          negative                                           headache
# 2          negative                                             gloomy
# 3          positive               wants to hang out with friends SOON!
# 4           neutral  We want to trade with someone who has Houston ...
# ...             ...                                                ...
# 39995       neutral                                                nan
# 39996      positive                                              Happy
# 39997      positive                                 Happy Mother`s Day
# 39998       neutral  WASSUP BEAUTIFUL!!! FOLLOW ME!!  PEEP OUT MY N...
# 39999       neutral  bullet train from tokyo    the gf and i have b...
#
# [40000 rows x 8 columns]

# %% [markdown]
# ## 원본 데이터중 학습/테스트 제외하고 한번도 안본 (감정 라벨링 안된) 애들을 찾자

# %%
orig_data_ = orig_data[orig_data.selected_text == 'nan']
orig_data_ = orig_data_[orig_data_.text != 'nan']

# %%
orig_data_
# Out:
#            textID  sentiment        author  \
# 0      1956967341      empty    xoshayzers
# 6      1956968487    sadness      ShansBee
# 7      1956968636      worry      mcsleazy
# 9      1956969172    sadness    Ingenue_Em
# 15     1956971077    sadness        Sim_34
# ...           ...        ...           ...
# 39982  1753905020    neutral      2str20lt
# 39983  1753905073    neutral      ABZQuine
# 39990  1753918829    neutral       kdpaine
# 39993  1753918892    neutral    bushidosan
# 39994  1753918900  happiness  courtside101
#
#                                                     text  \
# 0      i know  i was listenin to bad habit earlier an...
# 6      I should be sleep, but im not! thinking about ...
# 7                   Hmmm. http://www.djhero.com/ is down
# 9                       I`m sorry  at least it`s Friday?
# 15         The storm is here and the electricity is gone
# ...                                                  ...
# 39982  hey guys, if you have something to ask, just a...
# 39983  not really just leaving flat now, on the looko...
# 39990  I think the lesson of the day is not to have l...
# 39993  haha, yeah. Twitter has many uses. For me it`s...
# 39994                      Succesfully following Tayla!!
#
#                                                 old_text       aux_id  \
# 0      @tiffanylue i know  i was listenin to bad habi...  p1000000000
# 6      I should be sleep, but im not! thinking about ...  p1000000001
# 7                   Hmmm. http://www.djhero.com/ is down   2dfbe0b7fb
# 9             @kelcouch I'm sorry  at least it's Friday?   6d846d7d50
# 15         The storm is here and the electricity is gone  p1000000002
# ...                                                  ...          ...
# 39982  hey guys, if you have something to ask, just a...  p1000008981
# 39983  @Astronick not really just leaving flat now, o...  p1000008982
# 39990  @shonali I think the lesson of the day is not ...  p1000008983
# 39993  @sendsome2me haha, yeah. Twitter has many uses...  p1000008984
# 39994                      Succesfully following Tayla!!   bd499c0bf7
#
#       new_sentiment selected_text
# 0               NaN           nan
# 6               NaN           nan
# 7          negative           nan
# 9          negative           nan
# 15              NaN           nan
# ...             ...           ...
# 39982           NaN           nan
# 39983           NaN           nan
# 39990           NaN           nan
# 39993           NaN           nan
# 39994      positive           nan
#
# [12167 rows x 8 columns]

# %% [markdown]
# ## 한번도 안본 데이터는 이렇게 얻을 수 있고, unseen.csv로 저장
# - 여기에 감정 수도 라벨링!
# - 이거 진짜로 한번도 안본데이터인지 확인 필요할거같은게 test랑 겹치는거같음

# %%
unseen_data = orig_data_[orig_data_.new_sentiment.isnull()].reset_index(drop=True)

# %%
unseen_data
# Out:
#           textID   sentiment          author  \
# 0     1956967341       empty      xoshayzers
# 1     1956968487     sadness        ShansBee
# 2     1956971077     sadness          Sim_34
# 3     1956972116     neutral           jansc
# 4     1956972359     sadness  xamountoftruth
# ...          ...         ...             ...
# 8600  1753904526  enthusiasm      Freakonomy
# 8601  1753905020     neutral        2str20lt
# 8602  1753905073     neutral        ABZQuine
# 8603  1753918829     neutral         kdpaine
# 8604  1753918892     neutral      bushidosan
#
#                                                    text  \
# 0     i know  i was listenin to bad habit earlier an...
# 1     I should be sleep, but im not! thinking about ...
# 2         The storm is here and the electricity is gone
# 3     No Topic Maps talks at the Balisage Markup Con...
# 4     so tired and i think i`m definitely going to g...
# ...                                                 ...
# 8600               Hey Sarah! Hws u? Hope u remember me
# 8601  hey guys, if you have something to ask, just a...
# 8602  not really just leaving flat now, on the looko...
# 8603  I think the lesson of the day is not to have l...
# 8604  haha, yeah. Twitter has many uses. For me it`s...
#
#                                                old_text       aux_id  \
# 0     @tiffanylue i know  i was listenin to bad habi...  p1000000000
# 1     I should be sleep, but im not! thinking about ...  p1000000001
# 2         The storm is here and the electricity is gone  p1000000002
# 3     No Topic Maps talks at the Balisage Markup Con...  p1000000003
# 4     so tired and i think i'm definitely going to g...  p1000000004
# ...                                                 ...          ...
# 8600   @SarahSaner Hey Sarah! Hws u? Hope u remember me  p1000008980
# 8601  hey guys, if you have something to ask, just a...  p1000008981
# 8602  @Astronick not really just leaving flat now, o...  p1000008982
# 8603  @shonali I think the lesson of the day is not ...  p1000008983
# 8604  @sendsome2me haha, yeah. Twitter has many uses...  p1000008984
#
#      new_sentiment selected_text
# 0              NaN           nan
# 1              NaN           nan
# 2              NaN           nan
# 3              NaN           nan
# 4              NaN           nan
# ...            ...           ...
# 8600           NaN           nan
# 8601           NaN           nan
# 8602           NaN           nan
# 8603           NaN           nan
# 8604           NaN           nan
#
# [8605 rows x 8 columns]

# %%
del_idxs = []
for idx, text1 in enumerate(unseen_data.text.values):
    for text2 in test_data.text.values:
        if set(text1.split()) == set(text2.split()):
            print(text1)
            print(text2)
            del_idxs.append(idx)
# Out:
# welcome
# welcome
# Thank you!
# Thank you!
# Thank you!
# Thank you!
# Thank you!
# Thank you!
# Thank you!
# Thank you!
# Thank you!
# Thank you!
# hey
# hey hey
# Thank you!
# Thank you!
# Thank you!
# Thank you!
# Thank you!
# Thank you!
# Thank you!
# Thank you!

# %%
del_idxs
# Out:
# [4662, 4729, 4990, 5272, 5706, 6386, 7241, 7614, 8037, 8161, 8253]

# %%
unseen_data = unseen_data.drop(del_idxs).reset_index(drop=True)

# %%
unseen_data
# Out:
#           textID   sentiment          author  \
# 0     1956967341       empty      xoshayzers
# 1     1956968487     sadness        ShansBee
# 2     1956971077     sadness          Sim_34
# 3     1956972116     neutral           jansc
# 4     1956972359     sadness  xamountoftruth
# ...          ...         ...             ...
# 8589  1753904526  enthusiasm      Freakonomy
# 8590  1753905020     neutral        2str20lt
# 8591  1753905073     neutral        ABZQuine
# 8592  1753918829     neutral         kdpaine
# 8593  1753918892     neutral      bushidosan
#
#                                                    text  \
# 0     i know  i was listenin to bad habit earlier an...
# 1     I should be sleep, but im not! thinking about ...
# 2         The storm is here and the electricity is gone
# 3     No Topic Maps talks at the Balisage Markup Con...
# 4     so tired and i think i`m definitely going to g...
# ...                                                 ...
# 8589               Hey Sarah! Hws u? Hope u remember me
# 8590  hey guys, if you have something to ask, just a...
# 8591  not really just leaving flat now, on the looko...
# 8592  I think the lesson of the day is not to have l...
# 8593  haha, yeah. Twitter has many uses. For me it`s...
#
#                                                old_text       aux_id  \
# 0     @tiffanylue i know  i was listenin to bad habi...  p1000000000
# 1     I should be sleep, but im not! thinking about ...  p1000000001
# 2         The storm is here and the electricity is gone  p1000000002
# 3     No Topic Maps talks at the Balisage Markup Con...  p1000000003
# 4     so tired and i think i'm definitely going to g...  p1000000004
# ...                                                 ...          ...
# 8589   @SarahSaner Hey Sarah! Hws u? Hope u remember me  p1000008980
# 8590  hey guys, if you have something to ask, just a...  p1000008981
# 8591  @Astronick not really just leaving flat now, o...  p1000008982
# 8592  @shonali I think the lesson of the day is not ...  p1000008983
# 8593  @sendsome2me haha, yeah. Twitter has many uses...  p1000008984
#
#      new_sentiment selected_text
# 0              NaN           nan
# 1              NaN           nan
# 2              NaN           nan
# 3              NaN           nan
# 4              NaN           nan
# ...            ...           ...
# 8589           NaN           nan
# 8590           NaN           nan
# 8591           NaN           nan
# 8592           NaN           nan
# 8593           NaN           nan
#
# [8594 rows x 8 columns]

# %%
unseen_data.to_csv('unseen_no_dup.csv', index=False)

# %% [markdown]
# ## Pseudo Labeling 결과
# - unseen.csv에 대해 senti_cls에서 감정 라벨링 -> pseudo_senti.csv 생성
# - pseudo_senti.csv에 대해서 senti_ext에서 selected_text 라벨링

# %%
pseudo = pd.read_csv(os.path.join('dataset', 'pseudo_selected.csv'))
pseudo['text'] = pseudo.apply(lambda row: str(row.text).strip(), axis=1)

# %%
pseudo
# Out:
#            textID                                               text  \
# 0      1695882869  But Chevy & Chrysler may soon be owned by the ...
# 1      1751851500  aww that`s sweet! i made a home made card and ...
# 2      56f5217a16                              happy birthday ness!!
# 3      1752917807  Yes ma`am lol. I`ll switch to my inspirational...
# 4      1694792115                music-habits - I`ll join your study
# ...           ...                                                ...
# 12018  1753852785  woah in the uk it isn`t mothers day werid! I`v...
# 12019  1961890740  is there a program that tells you when someone...
# 12020  1962264095                               *eekkk* back to work
# 12021  136b1926c9                         Cool. That`d be fantastic!
# 12022  1965652759  Now it let me upload a pic, but I don`t have o...
#
#       sentiment                                      selected_text
# 0       neutral   But Chevy & Chrysler may soon be owned by the...
# 1      positive                                  aww that`s sweet!
# 2      positive                              happy birthday ness!!
# 3       neutral   Yes ma`am lol. I`ll switch to my inspirationa...
# 4       neutral                music-habits - I`ll join your study
# ...         ...                                                ...
# 12018  positive                                            awesome
# 12019  negative                                               Lost
# 12020   neutral                               *eekkk* back to work
# 12021  positive                         Cool. That`d be fantastic!
# 12022   neutral   Now it let me upload a pic, but I don`t have ...
#
# [12023 rows x 4 columns]

# %%
pseudo['text'] = pseudo.apply(lambda row: str(row.text).strip(), axis=1)

# %% [markdown]
# ## pseudo labled data가 학습/테스트셋에 있는지 체크
# 해야할일이 뭐냐면
# - 테스트 데이터에서 아래처럼 체크한 뒤 트레인 데이터에 포함되는 내용 지워야하고
# - 안본 데이터에 대해서 감정을 태깅 했으니까
# - 그렇게 많지 않긴한데...
#     - 테스트 데이터랑 학습 데이터는 거의 안겹치고
#     - 학습 데이터랑 (테스트+언씬) 데이터는 겹치는게 쫌 있음 (이게 사실 바로 전걸 포함함)

# %% [markdown]
# ## 학습셋에 존재하는 데이터 필터링

# %%
del_idxs = []
for idx, text1 in enumerate(pseudo.text.values):
    if idx%500 == 0:
        print(idx)
    for text2 in train_data.text.values:
        if set(text1.split()) == set(text2.split()):
            print(text1)
            print(text2)
            del_idxs.append(idx)
# Out:
# 0
# thanx
# thanx
# thanx
# thanx
# Good Morning!
# Good Morning!
# 500
# 1000
# 1500
# happy mothers day
# happy mothers day
# 2000
# Happy Star Wars Day!!!
# Happy Star Wars Day!!!
# #Java is not working - hmph!  Can`t upload photos to #Facebook.
# #Java is not working - hmph!  Can`t upload photos to #Facebook.
# Where`d the songs go on the site, I want 'Do You' on this computer too
# Where`d the songs go on the site, I want 'Do You' on this computer too
# 2500
# check out review for the movie Fighting - http://bit.ly/Fle9j Hilarious!! leave this guy a comment!
# check out review for the movie Fighting - http://bit.ly/Fle9j  Hilarious!! leave this guy a comment!
# 3000
# my cousin is in jail for shoplifting and drugs she is 16! im upset please help me feel better
# my cousin is in jail for shoplifting and drugs she is 16! im upset please help me feel better
# 3500
# good morning!
# good morning!
# i think my niece got me sickee  lame.
# i think my niece got me sickee  lame.
# 4000
# lol exams i didn`t go to mcast or other school i finished form 5 and that`s it soo disappointed in myself
# lol exams i didn`t go to mcast or other school i finished form 5 and that`s it soo disappointed in myself
# 4500
# 5000
# WHAT ABOUT ME ??  I VOTE EVERY DAY FOR YOU !!!!!
# WHAT ABOUT ME ??  I VOTE EVERY DAY FOR YOU !!!!!
# 5500
# Sensation Ocean of White Portugal: absolutely amazing  Adoreiii!
# Sensation Ocean of White Portugal: absolutely amazing  Adoreiii!
# 6000
# 6500
# 7000
# my cousin is in jail for shoplifting and drugs she is 16! im upset please help me feel better
# my cousin is in jail for shoplifting and drugs she is 16! im upset please help me feel better
# 7500
# *hug*
# *hug*
# good morning!
# good morning!
# 8000
# Happy Mothers Day
# Happy Mothers Day
# Hey everyone! I just mixed the first single....!  'Why R U' ...I`m sooo excited!
# Hey everyone! I just mixed the first single....!  'Why R U' ...I`m sooo excited!
# 8500
# 9000
# Thanks so much!
# Thanks so much!
# I see I see
# I see
# I see I see
# I see
# 9500
# 10000
# Plane tickets to UK and everywhere to Europe are BEYOND cheap (for June-Oct!!), but there`s NO gig in the near future announced yet
# Plane tickets to UK and everywhere in Europe are BEYOND cheap (for June-Oct!!), but there`s NO gig in the near future announced yet
# I miss you
# I miss you
# I miss you
# I miss you
# The link doesn`t work
# The link doesn`t work
# 10500
# I did that once
# I did that once
# I can`t vote for you    they have stopped the voting
# I can`t vote for you  they have stopped the voting
# 11000
# 11500
# 12000

# %%
len(del_idxs)
# Out:
# 28

# %%
pseudo = pseudo.drop(del_idxs).reset_index(drop=True)

# %%
pseudo
# Out:
#            textID                                               text  \
# 0      1695882869  But Chevy & Chrysler may soon be owned by the ...
# 1      1751851500  aww that`s sweet! i made a home made card and ...
# 2      56f5217a16                              happy birthday ness!!
# 3      1752917807  Yes ma`am lol. I`ll switch to my inspirational...
# 4      1694792115                music-habits - I`ll join your study
# ...           ...                                                ...
# 11968  1753852785  woah in the uk it isn`t mothers day werid! I`v...
# 11969  1961890740  is there a program that tells you when someone...
# 11970  1962264095                               *eekkk* back to work
# 11971  136b1926c9                         Cool. That`d be fantastic!
# 11972  1965652759  Now it let me upload a pic, but I don`t have o...
#
#       sentiment                                      selected_text
# 0       neutral   But Chevy & Chrysler may soon be owned by the...
# 1      positive                                  aww that`s sweet!
# 2      positive                              happy birthday ness!!
# 3       neutral   Yes ma`am lol. I`ll switch to my inspirationa...
# 4       neutral                music-habits - I`ll join your study
# ...         ...                                                ...
# 11968  positive                                            awesome
# 11969  negative                                               Lost
# 11970   neutral                               *eekkk* back to work
# 11971  positive                         Cool. That`d be fantastic!
# 11972   neutral   Now it let me upload a pic, but I don`t have ...
#
# [11973 rows x 4 columns]

# %%
pseudo = pseudo.drop_duplicates(['text'], keep='first').reset_index(drop=True)

# %%
pseudo.to_csv('./dataset/pseudo_selected_no_dup.csv')

# %% [markdown]
# ## 문제가 되는 문장 (영어가 아닌 문장, 삭제해버리기 -> 코드에 반영 완료)
# - 혹시 모르니 내일 빈칸 개수가 안맞는지 여부 체크해보기
#     - 아마 데이터셋.py 에서 제대로 처리할듯?

# %%
def isEnglish(s):
    try:
        s.encode(encoding='utf-8').decode('ascii')
    except UnicodeDecodeError:
        return False
    else:
        return True

# %%
a = 'I did one last night  it will be available in dvd, blue ray, and digital download via the iTunes store by the end of the week'
' '.join(a.split())
# Out:
# 'I did one last night it will be available in dvd, blue ray, and digital download via the iTunes store by the end of the week'

# %%
a = ' Photo: jdperry: Seriously, theseï¿½pictures make my day. Hahaha. Iï¿½always just go aroundï¿½saying ï¿½OMG did you...'
isEnglish(a)
# Out:
# False

# %%
ids = []
for idx, text in enumerate(pseudo.text):
    row = pseudo.iloc[idx]
    if not isEnglish(text):
        print(idx, text, row.selected_text)
        ids.append(idx)
    #else:
    #    if row.selected_text.strip() not in text.strip():
    #        print("@@", text.strip(), '\n', row.selected_text.strip())
# Out:
# 411 Heathrow Connect is ï¿½7.40,i thought it was a bargain (express is 15),but then it terminated at Hayes/Harlington and i had to take a bus  Heathrow Connect is ï¿½7.40,i thought it was a bargain (express is 15),but then it terminated at Hayes/Harlington and i had to take a bus
# 451 God, I`ll miss my bf so ****` much!  It`s only 2 months now *snï¿½ff*  miss
# 483 at economics i wanna go homeeeeeee  im tired and i hate the teacher.  and iï¿½m sick of half of my classmates and i wanna go home and sleep  hate
# 638 vll iwas mit kï¿½se  vll iwas mit kï¿½se
# 747 Photovia novusnovendo) ï¿½o_0ï¿½*giggles*ï¿½who am i kidding? heï¿½s probably ****  but def my type, hey now! http://tumblr.com/x2k1wgbpm  Photovia novusnovendo) ï¿½o_0ï¿½*giggles*ï¿½who am i kidding? heï¿½s probably **** but def my type, hey now! http://tumblr.com/x2k1wgbpm
# 828 ist im der Haus... or something like that.  Guten morgen, Frï¿½ulein!  ist im der Haus... or something like that. Guten morgen, Frï¿½ulein!
# 950 haha xD LMFAOO ;p yasemin ist sehr sï¿½ï¿½  we rawk or what? xD  haha xD LMFAOO ;p yasemin ist sehr sï¿½ï¿½ we rawk or what? xD
# 979 .up cï¿½m on anh  ko the chiu noi no~i nhï¿½ Tifa roi :-D, thang Cloud danh dam gi mac ke no :'>  .up cï¿½m on anh ko the chiu noi no~i nhï¿½ Tifa roi :-D, thang Cloud danh dam gi mac ke no :'>
# 998 Good morning... Iï¿½m soooo tierd  Good morning... Iï¿½m soooo tierd
# 1204 yesterday i missed the live chat  internet was the problem ï¿½ï¿½  missed
# 1232 _Guy Sorry about youï¿½re mom  But itï¿½s great to hear your dad is the best - then you forgive him the SPARKLE ?  _Guy Sorry about youï¿½re mom But itï¿½s great to hear your dad is the best - then you forgive him the SPARKLE ?
# 1243 This completes today the 4th of Mayï¿½s entry. For the new day, invite a friend to come along to reflectively in-joy the read ï¿½  ï¿½  in-joy
# 1339 haizzz, hem cï¿½n ai, t? ?i ?n ?ï¿½y... ?ï¿½i b?ng quï¿½  Bibi c? nhï¿½ trï¿½i cï¿½y  haizzz, hem cï¿½n ai, t? ?i ?n ?ï¿½y... ?ï¿½i b?ng quï¿½ Bibi c? nhï¿½ trï¿½i cï¿½y
# 1459 Morniiing twitter  eating cereales and watching BLG dvd like every sunday morning ^^ï¿½  Morniiing twitter eating cereales and watching BLG dvd like every sunday morning ^^ï¿½
# 1564 I want to read my book, but my conscience is telling me to kill off joe   ï¿½ï¿½l Berto!  kill
# 1584 Iï¿½m also watching a movie with friends (twilight)  Iï¿½m also watching a movie with friends (twilight)
# 1590 Hockey was so fukinï¿½ good  **** you hole! xD  Hockey was so fukinï¿½ good **** you hole! xD
# 1655 Sï¿½i Gï¿½n sï¿½ng n?ng chi?u m?a  Sï¿½i Gï¿½n sï¿½ng n?ng chi?u m?a
# 1682 Won a diamond for my compï¿½tition  , yaayy tomorow its the DIAMOND DANCE OFF !! Were the best  .. Still in montrï¿½al !!  Won a diamond for my compï¿¿½tition , yaayy tomorow its the DIAMOND DANCE OFF !! Were the best
# 1885 Hehe,  in  sta se malce preve? vï¿½ivela v v?erajï¿½nji Dark was the night koncert  No, ob takem lineupu...  Hehe, in sta se malce preve? vï¿½ivela v v?erajï¿½nji Dark was the night koncert No, ob takem lineupu...
# 1909 nï¿½o te vi onteeeeeeem  nï¿½o te vi onteeeeeeem
# 1960 kicking it incredibly old-schoolï¿½ I whole-heartedly approved  I whole-heartedly approved
# 2094 not too bad,but I did get some bad news this afternoon, I got stopped by the police   brake lights out but it`s ï¿½30 fine  bad
# 2108 Mother`s Day - cherrylolita: Thatï¿½s not true. My bad - I didnï¿½t check it  Thank you  http://tumblr.com/xxv1qz4ge  Mother`s Day - cherrylolita: Thatï¿½s not true. My bad - I didnï¿½t check it Thank you http://tumblr.com/xxv1qz4ge
# 2172 Aserejï¿½, ja deje dejebe tudejebe de  sebiunouva majabi an de bugui an de buididipï¿½    learning spanish through a song  Aserejï¿½, ja deje dejebe tudejebe de sebiunouva majabi an de bugui an de buididipï¿½ learning spanish through a song
# 2177 Y360 rï¿½t b?t c? ??ng user ch?y ??n r?i thï¿½ l?i nhanh thï¿½i  Y360 rï¿½t b?t c? ??ng user ch?y ??n r?i thï¿½ l?i nhanh thï¿½i
# 2465 iï¿½m ill.. bueeee..  ill..
# 2944 : oï¿½i, ph?i `ru` cho bï¿½ ï¿½ ng?, tr??c khi b? th?y cï¿½i r?ng trï¿½i cï¿½y nï¿½y, ?ï¿½i mua m?i th? 1 kg ?? ?n thï¿½ ch?t  : oï¿½i, ph?i `ru` cho bï¿½ ï¿½ ng?, tr??c khi b? th?y cï¿½i r?ng trï¿½i cï¿½y nï¿½y, ?ï¿½i mua m?i th? 1 kg ?? ?n thï¿½ ch?t
# 3043 Fï¿½licitations!  Fï¿½licitations!
# 3082 d? ?oï¿½n mï¿½nh s? coi cï¿½i nh?c k?ch nï¿½y 3 l?n ?? n?m b?t ???c g?n ??y ?? tinh th?n vï¿½ cï¿½c khï¿½a c?nh c?a nï¿½  d? ?oï¿½n mï¿½nh s? coi cï¿½i nh?c k?ch nï¿½y 3 l?n ?? n?m b?t ???c g?n ??y ?? tinh th?n vï¿½ cï¿½c khï¿½a c?nh c?a nï¿½
# 3161 : bibi em  Th? lï¿½ 1 chï¿½m dï¿½u ?ï¿½ ra ?i...  : bibi em Th? lï¿½ 1 chï¿½m dï¿½u ?ï¿½ ra ?i...
# 3297 _sue_li natï¿½rlich  _sue_li natï¿½rlich
# 3314 ava nï¿½y c?ng ch? cï¿½ 3 mï¿½u nh?? :-/  thui, hem sao em ?, c? h?i cï¿½n nhï¿½u m?,  ava nï¿½y c?ng ch? cï¿½ 3 mï¿½u nh?? :-/ thui, hem sao em ?, c? h?i cï¿½n nhï¿½u m?,
# 3342 Canï¿½t stop loosing.  Worst month results ever... Bubble two times in a row.  Worst
# 3381 Itï¿½s NO voting vs anything - simple but true: yr *Stronger* cover is the BEST - w/o me *looking through pink glasses*!  BEST
# 3411 despertando megadespistado, me ire a la u y luego full fin de semana on the beach, saldrï¿½ en wild on!  despertando megadespistado, me ire a la u y luego full fin de semana on the beach, saldrï¿½ en wild on!
# 3552 itï¿½s raining... I hate rain...  going to shop and drink coffee all day.  hate
# 3661 Hehe it`s an option if the (advertising) world wasn`t such a mess! So I might in future! We`re on same time yes. Lï¿½get i dï¿½g?  Hehe it`s an option if the (advertising) world wasn`t such a mess! So I might in future! We`re on same time yes. Lï¿½get i dï¿½g?
# 3670 Hasta maï¿½ana twitters  Hasta maï¿½ana twitters
# 3973 _nessa Hiyaaa hannah asked me if i wanted to come to Girls Aloud  i wil see if i can **** some money somwhere is it ï¿½33 you need?  _nessa Hiyaaa hannah asked me if i wanted to come to Girls Aloud i wil see if i can **** some money somwhere is it ï¿½33 you need?
# 4214 Esse ï¿½ o Wolverine que eu conheï¿½o http://tinyurl.com/c577ny , by noiva !  Esse ï¿½ o Wolverine que eu conheï¿½o http://tinyurl.com/c577ny , by noiva !
# 4365 ï¿½ miss my future, ï¿½ wanna see her  ï¿½ for **** sure don`t wanna wait til monday  miss
# 4427 AHHH - Whatchu talkinï¿½ baby?  HAHAHA I canï¿½t believe youu:O heh, actually I can. Life is worth taking risks... http://tumblr.com/xs81qy54s  Life is worth taking risks...
# 4555 Pas si terrific que ï¿½a ce twitterrific  terrific
# 4794 Oh joy its gong to be a long weekebd... Yipee :*Â¡  Oh joy
# 4871 Bom dia, Uï¿½tisson!  Bom dia, Uï¿½tisson!
# 5027 jï¿½ estou a ver que sim  , aqui - http://en.wikipedia.org/wiki/Mother`s_day#Dates_around_the_world  jï¿½ estou a ver que sim , aqui - http://en.wikipedia.org/wiki/Mother`s_day#Dates_around_the_world
# 5176 i saw some lovely skinny jeans today for ï¿½3 at a charity shop, but they were just a little bit tight on my thighs.  ahhh so annoying  i saw some lovely skinny jeans today for ï¿½3 at a charity shop, but they were just a little bit tight on my thighs. ahhh so annoying
# 5195 I would vote for you Miley but I live in Ireland  You`ll be fine  Good luck! Slï¿½n!(bye in irish ) Sorcha xxxx  Good luck!
# 5287 or you could geocode the events with the  apiï¿½s  or you could geocode the events with the apiï¿½s
# 5387 iis back homee. Boredd. chillinq w| qrandma  ï¿½ ily Granny  iis back homee. Boredd. chillinq w| qrandma ï¿½ ily Granny
# 5984 Thanks b?n Tu?n . Vi?t ban ?ï¿½m, khï¿½ng ch?ng vï¿½ con khï¿½ng qu?y  Thanks
# 5988 e ah! Ghost in the Shell ï¿½ meu anime favorito. assistiu?  e ah! Ghost in the Shell ï¿½ meu anime favorito. assistiu?
# 6212 _luna everything , I donï¿½t know how explain  simply itï¿½s patetic  _luna everything , I donï¿½t know how explain simply itï¿½s patetic
# 6459 ok i just spent like ï¿½50 on soundtracks, a galaxy class starship and EVE online. sigh  ok i just spent like ï¿½50 on soundtracks, a galaxy class starship and EVE online. sigh
# 6554 Nicklaus!!!!!  Iï¿½m MAD I missed you out in VA last night, I was gonna snatch you up and make you wifey!!! 2009 is MINEE  MAD
# 6949 Har varit pï¿½ Hannah Montana the movie   // cool http://gykd.net  cool
# 6977 _Hisashi Mï¿½y em mï¿½ torrent thï¿½ bï¿½ ch? trï¿½n nhï¿½ ?ang Thiï¿½n Long l?i ch?y xu?ng ?i?u tra  _Hisashi Mï¿½y em mï¿½ torrent thï¿½ bï¿½ ch? trï¿½n nhï¿½ ?ang Thiï¿½n Long l?i ch?y xu?ng ?i?u tra
# 7183 Praise the advantages of todays copy protection: can not run my fresh installed 3D app, since the licensing system donï¿½t let me.  Praise the advantages
# 7304 depois tu pode ver outras sï¿½ries. te indico two and a half men e the big bang theory. bem diferentes de 90210. comï¿½dias.  depois tu pode ver outras sï¿½ries. te indico two and a half men e the big bang theory. bem diferentes de 90210. comï¿½dias.
# 7330 ? listening No Doubt ï¿½  ' It`s My Life ' 59 listeners<< ohh yeahhh thanks   ? http://blip.fm/~5z4va  thanks
# 7367 pq vc nï¿½o pediu amor  pq vc nï¿½o pediu amor
# 7630 What`s your doggieï¿½s name? so cute... Same breed as the Obamaï¿½s  cute...
# 7689 the day goes on and on...i think im gonna write a song about it! still thinking itï¿½s impossible for me to get a true friend  why????  impossible
# 7711 ï¿½ï¿½We are ready for the new generation!!...Oh yeah...We are a Backstreet fans and we are proud about it!!  proud
# 7730 te gustarï¿½!  te gustarï¿½!
# 8085 meagï¿½evï¿½s.com  meagï¿½evï¿½s.com
# 8140 ?ang cho con hamster m?p t?p th? d?c b?ng cï¿½ch: b? vï¿½o banh ch?y lï¿½ng vï¿½ng trong phï¿½ng  ?ang cho con hamster m?p t?p th? d?c b?ng cï¿½ch: b? vï¿½o banh ch?y lï¿½ng vï¿½ng trong phï¿½ng
# 8176 LMï¿½ï¿½oï¿½o! my job is funn  funn
# 8354 quem ï¿½ Katy??  quem ï¿½ Katy??
# 8394 j`ai pas vu passer ton ReBlip annoncï¿½ de *Pump Up The Jam*....    pb d`adresse URL ?  j`ai pas vu passer ton ReBlip annoncï¿½ de *Pump Up The Jam*.... pb d`adresse URL ?
# 8513 oh yes some are quite nice! and my `photoshop` liep zojuist vast. so now I have to start over painting Rï¿½isï¿½ns glove  nice!
# 8741 _Guy Me neither  But itï¿½s getting better  better
# 8890 .up cï¿½m on anh  ko the chiu no~i noi nhï¿½ Tifa roi :-D, thang Cloud danh dam gi mac ke no :'>  .up cï¿½m on anh ko the chiu no~i noi nhï¿½ Tifa roi :-D, thang Cloud danh dam gi mac ke no :'>
# 8907 is not paying ï¿½8 per hr for Internet access so may be limited to Twitter via txt  is not paying ï¿½8 per hr for Internet access so may be limited to Twitter via txt
# 9253 T ere is a visio document but itï¿½s continuously changing until now.  T ere is a visio document but itï¿½s continuously changing until now.
# 9343 Photo: jdperry: Seriously, theseï¿½pictures make my day.  Hahaha. Iï¿½always just go aroundï¿½saying ï¿½OMG did you... http://tumblr.com/xzn1pir8s  Seriously, theseï¿¿½pictures make my day.
# 9349 forgot his access card in the carï¿½too lazy to fetch it  forgot his access card in the carï¿¿½too lazy
# 9355 Look what I got for lunch today!! A cheese empanada and tequeï¿½os Venezuelan style!!!! I miss this soooo much!  http://yfrog.com/14lyij  I miss this soooo much!
# 9425 Tell Me What Dog You Are Like -- Most & Iï¿½ll Tell You If You Are An Entrepreneur Or Not  http://is.gd/wjeJ New Blog Post  Tell Me What Dog You Are Like -- Most & Iï¿½ll Tell You If You Are An Entrepreneur Or Not http://is.gd/wjeJ New Blog Post
# 9459 Lord Have Mercy ... TECHNOLOGY ! So much Tattos MON DIEU ï¿½ï¿½ a dï¿½ faire mal !  Lord Have Mercy ... TECHNOLOGY ! So much Tattos MON DIEU ï¿½ï¿½ a dï¿½ faire mal !
# 9488 Erm ovaj 'video twitter' iz Tweetia ne radi. Niï¿½ta od microcastinga  Erm ovaj 'video twitter' iz Tweetia ne radi. Niï¿½ta od microcastinga
# 9600 Nemï¿½m zdrojï¿½ky Mozilly ani Perl, takï¿½e z?stanu u svï¿½ vï¿½ry ve schopnosti Ohlohu  Nemï¿½m zdrojï¿½ky Mozilly ani Perl, takï¿½e z?stanu u svï¿½ vï¿½ry ve schopnosti Ohlohu
# 9874 Ouvindo 'The Wonders - All my only dreams', a melhor banda do mundo que nunca existiu. Pra comeï¿½ar bem o dia.  Ouvindo 'The Wonders - All my only dreams', a melhor banda do mundo que nunca existiu. Pra comeï¿½ar bem o dia.
# 9950 ï¿½Chillingoutnow Just testing how to work Twitter from my phone  ï¿½Chillingoutnow Just testing how to work Twitter from my phone
# 9962 will do  it`s only ï¿½34.99 on play.com, so might just buy it, it certainly looks and sounds good enough! i`m excited for it lol  excited
# 9993 fï¿½hlt sich ganz so an #montezuma #iphone  fï¿½hlt sich ganz so an #montezuma #iphone
# 10465 Lï¿½ mï¿½y theo lï¿½n giï¿½ tï¿½i bay kh?p tr?i  Lï¿½ mï¿½y theo lï¿½n giï¿½ tï¿½i bay kh?p tr?i
# 10511 ohï¿½ unfortunately not  unfortunately
# 10600 tikcets are only ï¿½91...each...BUT I SO WANT TO GO  I SO WANT TO GO
# 10704 lï¿½m ti?c m?ng MM gia nh?p h?i ?i ah  lï¿½m ti?c m?ng MM gia nh?p h?i ?i ah
# 10747 awww how cuuute, mine follows me when i showers and peeï¿½s and wherever i go but refuses to lay still in the bed  awww how cuuute, mine follows me when i showers and peeï¿½s and wherever i go but refuses to lay still in the bed
# 10908 Start of diet today  I think I have to face I will never get back down to 77kilos (unless I cut a leg off)ï¿½  I will never get back down
# 11174 Oh, final msg - Why didn`t you review my boardgame Bookchaseï¿½ when you were on telly? We didn`t even get a nice letter..  We didn`t even get a nice letter..
# 11256 _Guy Maybe we will meet later again my friend - would luv too )) Iï¿½m still at the office and have a lot of work  luv
# 11287 'nhi?p ?nh gia' ? ?ï¿½y lï¿½ ch? cï¿½c b?n t? x?ng lï¿½ '?am mï¿½ nhi?p ?nh'. Cï¿½n ng??i thï¿½ch ch?p ?nh thï¿½ 99% dï¿½n s? r?i  'nhi?p ?nh gia' ? ?ï¿½y lï¿½ ch? cï¿½c b?n t? x?ng lï¿½ '?am mï¿½ nhi?p ?nh'. Cï¿½n ng??i thï¿½ch ch?p ?nh thï¿½ 99% dï¿½n s? r?i
# 11322 i would be doing the same thing pero la lavadora se daï¿½o  i would be doing the same thing pero la lavadora se daï¿½o
# 11418 _carter ah nick youï¿½ve set the vid to private  do you not want everyone 2 see it or has it been a mistake?  mistake?
# 11663 So disappointed about the talent lineup for 'Reventï¿½n Super Estrella 2009'...hmm...Have the feeling I won`t get tix this time around.  disappointed
# 11786 Video: Todayï¿½s video blog/vlogï¿½thing.  http://tumblr.com/xye1ph36b  Video: Todayï¿½s video blog/vlogï¿½thing. http://tumblr.com/xye1ph36b
# 11791 broken little toe? vai the doctor! Hoje vocï¿½ vai na 89FM, quero vï¿½-lo atravï¿½s da Internet. got to see it  broken
# 11863 Iï¿½m Back, sorry, lot a work  news?  sorry,
# 11900 My acid refulx is acting upï¿½probably the worst it`s been in months. I don`t think I`ll be getting any sleep tonight.  worst
# 11970 On a boat. On the way out to Norrï¿½ra. Gonna chill for a while, Party tonight!  Gonna chill
# 12025 jï¿½ passo o link  jï¿½ passo o link

# %%
len(ids)
# Out:
# 105

# %%
pseudo = pseudo.drop(ids).reset_index(drop=True)

# %%
pseudo
# Out:
#            textID                                               text  \
# 0      1694291488                              you are so sexy mama!
# 1      1963588805  shout out to all the people goin to prom & iis...
# 2      64b297c15e  says my new layout is so cute x) see the cutie...
# 3      1753094743         your right, it is a great plant  i love it
# 4      1965986606  7pm on a Fri night & I`m sitting at home alone...
# ...           ...                                                ...
# 12029  1753788294  sorry i havent tweeted in a while- i was on ho...
# 12030  1961871203                               aw my dear i`m sorry
# 12031  1962234541  noo  i only started 4th season on wednesday bu...
# 12032  136b1926c9                         Cool. That`d be fantastic!
# 12033  1965570758                       i miss my baby  hateeeeee it
#
#       sentiment                                      selected_text
# 0      positive                                               sexy
# 1      negative                                               miss
# 2      positive                                               cute
# 3      positive                                              great
# 4       neutral   7pm on a Fri night & I`m sitting at home alon...
# ...         ...                                                ...
# 12029   neutral   sorry i havent tweeted in a while- i was on h...
# 12030  negative                               aw my dear i`m sorry
# 12031   neutral   noo i only started 4th season on wednesday bu...
# 12032  positive                         Cool. That`d be fantastic!
# 12033  negative                        i miss my baby hateeeeee it
#
# [12034 rows x 4 columns]

# %%
pseudo.to_csv('pseudo_selected.csv', index=False)

# %% [markdown]
# ------------

# %% [markdown]
# ---------------------------

# %% [markdown]
# # 아래는 사전 기반 (실패작)

# %%
test_texts = dict()

for i, txt in enumerate(test_data.text):
    test_data[txt] = test_data.iloc[i].sentiment

# %%
# train_data = train_data[train_data.sentiment != 'empty']

# %% [markdown]
# ## 주어진 학습 데이터가 원래 무슨 감정이었는지?
# - 단순 매핑이 아니었네

# %%
def get_sent(text):
    testimonial = TextBlob(str(text))
    return testimonial.sentiment.polarity

# %%
sent_tup = set()
for i, _ in enumerate(orig_data.textID):
    row = orig_data.iloc[i]
    
    if row.text in texts_senti:
        if  texts_senti[row.text] == row.new_sentiment:
            print("?")
            print(row.sentiment, row.new_sentiment, '=>', texts_senti[row.text], '==>', get_sent(row.text), row.text)
        # sent_tup.add((row.sentiment, texts_senti[row.text], row.new_sentiment))
# Out:
# ?
# sadness negative => negative ==> 0.0 Layin n bed with a headache  ughhhh...waitin on your call...
# ?
# sadness negative => negative ==> 0.0 Funeral ceremony...gloomy friday...
# ?
# enthusiasm positive => positive ==> 0.25 wants to hang out with friends SOON!
# ?
# neutral neutral => neutral ==> 0.0 We want to trade with someone who has Houston tickets, but no one will.
# ?
# worry negative => negative ==> 0.0 Re-pinging : why didn`t you go to prom? BC my bf didn`t like my friends
# ?
# sadness negative => negative ==> 0.5 Charlene my love. I miss you
# ?
# neutral neutral => neutral ==> 0.0 cant fall asleep
# ?
# worry negative => negative ==> 0.0 Choked on her retainers
# ?
# sadness negative => negative ==> -0.3916666666666666 Ugh! I have to beat this stupid song to get to the next  rude!
# ?
# sadness negative => negative ==> -0.3 if u watch the hills in london u will realise what tourture it is because were weeks and weeks late  i just watch itonlinelol
# ?
# surprise neutral => neutral ==> 0.0 Got the news
# ?
# love neutral => neutral ==> 0.0 agreed
# ?
# sadness negative => negative ==> -0.4 So sleepy again and it`s not even that late. I fail once again.
# ?
# worry negative => negative ==> 1.0 lady gaga tweeted about not being impressed by her video leaking just so you know
# ?
# sadness negative => negative ==> 0.0 How are YOU convinced that I have always wanted you? What signals did I give off...**** I think I just lost another friend
# ?
# worry neutral => neutral ==> -0.22499999999999995 oh too bad! I hope it gets better. I`ve been having sleep issues lately too
# ?
# fun neutral => neutral ==> -0.4159090909090909 Wondering why I`m awake at 7am,writing a new song,plotting my evil secret plots muahahaha...oh **** it,not secret anymore
# ?
# worry negative => negative ==> 0.1 On my way home n having 2 deal w underage girls drinking gin on da bus while talking bout keggers......**** i feel old
# ?
# sadness negative => negative ==> -0.05833333333333335 i`m sorry people are so rude to you, isaac, they should get some manners and know better than to be so lewd!
# ?
# worry negative => negative ==> -0.15555555555555559 Damm servers still down  i need to hit 80 before all the koxpers pass me
# ?
# sadness negative => negative ==> -0.39999999999999997 Fudge.... Just BS`d that whole paper.... So tired.... Ugh I hate school.....  time to sleep!!!!!!!!!!!
# ?
# worry negative => negative ==> -0.8 I HATE CANCER. I HATE IT I HATE IT I HATE IT.
# ?
# hate negative => negative ==> -0.4 It is so annoying when she starts typing on her computer in the middle of the night!
# ?
# neutral negative => negative ==> 0.0 _123 i cant sleep
# ?
# neutral negative => negative ==> 0.0 I missed the bl***y bus!!!!!!!!
# ?
# neutral neutral => neutral ==> 0.31666666666666665 feels strong contractions but wants to go out.  http://plurk.com/p/wxidk
# ?
# neutral neutral => neutral ==> 0.0 SoCal!  stoked. or maybe not.. tomorrow
# ?
# sadness negative => negative ==> -0.15 _radio yeah :S i feel all funny cause i haven`t slept enough  i woke my mum up cause i was singing she`s not impressed :S you?
# ?
# worry neutral => neutral ==> 0.2857142857142857 I need skott right now
# ?
# neutral neutral => neutral ==> 0.0 has work this afternoon
# ?
# happiness positive => positive ==> 0.18125 mmm much better day... so far! it`s still quite early. last day of #uds
# ?
# worry negative => negative ==> -0.0625 just picked up her Blackberry from the middle of the street! Both she and it are crushed!
# ?
# worry negative => negative ==> 0.24285714285714285 Bed!!!!!... its time,..... hope i go to school tomorrow, all though i don`t feel very well right now
# ?
# worry positive => positive ==> 0.0 Ahh.  ... Well, I was hoping that I could learn some stuff on the way. ... Why not you and I work on separate things but also
# ?
# sadness negative => negative ==> 0.0 I`m having a problem with my photo here in twitter amf!!!...can`t see my face!
# ?
# neutral neutral => neutral ==> 0.0 , oh noooo!  if i blow a tire you`re reaaaally going to have to send up some batman smoke.
# ?
# neutral neutral => neutral ==> 0.0 wnna take a bath!!!!
# ?
# neutral positive => positive ==> 0.5 Chocolate milk is so much better through a straw. I lack said straw
# ?
# worry negative => negative ==> -0.4 why am i so tired?
# ?
# neutral neutral => neutral ==> 0.0 time diff and i`ve just been wrapped up in day to day stuff so i havent been tweeting. talk soon,must sleep...up in 6hrs
# ?
# neutral negative => negative ==> 0.0625 no way! **** that sucks B!  are you ok?
# ?
# worry negative => negative ==> -0.09999999999999999 sucks not being able to take days off of work or have the money to take the trip  so sad
# ?
# enthusiasm positive => positive ==> 0.7 bed...sorta. today was good, sara has strep thought Angelina does to; i shared a water with her B4 they told me, i will prob get it to
# ?
# neutral neutral => neutral ==> 0.0 But I got dibs on Sulu...
# ?
# worry negative => negative ==> -0.15 at once haha.  poor aby still gets sore!
# ?
# sadness neutral => neutral ==> 0.10000000000000002 diesel yaris... 70mpg  so sad its not available in the US. That`d be awesome.
# ?
# sadness negative => negative ==> 0.08333333333333336 I want to buy this great album but unfortunately i dont hav enuff funds  its 'long time noisy'
# ?
# sadness neutral => neutral ==> -0.8 in all honesty...pain   blech.
# ?
# sadness negative => negative ==> 0.13333333333333333 Ok ... the passengers ... no one is alive ... they`re all dead ... you just don`t know it til the end ... then you cry ...
# ?
# neutral neutral => neutral ==> -0.1 At home alone with not much to do
# ?
# worry negative => negative ==> 0.4166666666666667 ia so much! i haven`t really been happy with any of cooks choices for singles.
# ?
# sadness neutral => neutral ==> 0.4 i fell asleep on the beach and didn`t put on enough sunscreen  lol
# ?
# worry neutral => neutral ==> -0.2875 So i think my son might have the flu cause I def. just cleaned up a stanky puke mess  Poor pumkpin
# ?
# worry negative => negative ==> -0.09722222222222221 ...and all woman who transfer their first impressions (sexual/maternal) onto a less `threatening` man -- are themselves as weak as `Him`
# ?
# neutral positive => positive ==> 0.4 Brothers Bloom won`t be opening this weekend in El Paso.  I`ll just buy Brick and enjoy that until I can watch Brothers Bloom.
# ?
# neutral negative => negative ==> 0.0 says I miss plurking.  http://plurk.com/p/wxion
# ?
# worry negative => negative ==> -0.8 Bitten to blood by my cat, on my way for a rabies bacterin. Seems 7 shots for 2 months. Never wash my cats at home again, they hate water
# ?
# neutral neutral => neutral ==> 0.0 _Monk Neither are ELP!!
# ?
# worry negative => negative ==> -0.5 is sad that shin ae got married...and it wasn`t to alex
# ?
# worry negative => negative ==> 0.3 Sure you will tweet about this when you`re back, but news is abuzz about TR Knight`s leaving 'confirmed' today.  Muy triste.
# ?
# neutral neutral => neutral ==> 0.0 there was a mix up with my dentist appt this afternoon. so they rescheduled me for tomorrow @ 9am.
# ?
# worry neutral => neutral ==> 0.2 fresh prince and sleepy sleeps my nightly routine  gotta go to Dmv early tmrw
# ?
# hate negative => negative ==> 0.08333333333333333 dammit! hulu desktop has totally screwed up my ability to talk to a particular port on one of our dev servers. so i can`t watch and code
# ?
# worry negative => negative ==> 0.0 i am jealous of your mom talking to . i want to see you all our twittering is making me miss you
# ?
# worry neutral => neutral ==> 0.0 I can`t sleep...I keep thinking about the puppy I played with today
# ?
# neutral positive => positive ==> 0.0 what`s going on sweetheart?
# ?
# neutral negative => negative ==> -0.6499999999999999 How can it be so freaking difficult to get a system-wide spellchecker? ****, I`d settle for an office suite one. Stupid unhelpful Windows
# ?
# worry negative => negative ==> -0.078125 Last one month due to summer, strawberry is not availble in the Chennai markets!
# ?
# neutral neutral => neutral ==> 0.0 work at 6am. Gotta go to bed soon
# ?
# love positive => positive ==> 0.4125 correct! I ADORE him. I just plucked him up and put him under my arm cuz he was cryin.  All better now! Hahaha
# ?
# sadness neutral => neutral ==> 0.0 hiii im on my ipod...i cant fall asleep
# ?
# sadness negative => negative ==> 0.23828125 feels sad coz i wasnt able to play with the guys!!!  http://plurk.com/p/wxiux
# ?
# neutral neutral => neutral ==> 0.0 PrinceCharming
# ?
# hate negative => negative ==> -0.016666666666666663 @ cayogial i wanted to come to BZ this summer :/ not so sure anymore... a teacher`s life in the summer SUCKS
# ?
# worry negative => negative ==> 0.17708333333333331 First ever dropped call on my mobile. On a call to  no less! ( being charged for data even though I have a data pack  )
# ?
# hate positive => positive ==> 0.8 You win ... SIGH Rakeem
# ?
# worry neutral => neutral ==> -0.375 Oh no one minute too late! Oh well
# ?
# hate negative => negative ==> 0.5 THIS WEBSITE GAVE ME A VIRUS! When i opened it more windows kept POPPING up
# ?
# sadness positive => positive ==> 0.0 I wish she knew what she puts me through..She stole my heart, never gave it back..and occasionally she likes to be like look what I have!
# ?
# worry negative => negative ==> -0.4380952380952381 is up with a nasty cough i cant be sick i have a huge weekend ahead of me
# ?
# neutral negative => negative ==> -0.6 That was stone cold   Crazy....  ?
# ?
# boredom negative => negative ==> -0.4 i`m so tired
# ?
# neutral neutral => neutral ==> 0.0 shift time  bbye biochem waaaaahhhhhh!! http://plurk.com/p/wxizo
# ?
# neutral neutral => neutral ==> 0.5 I`m sure some1 will **** out and play. I`m workin through til midnight.
# ?
# neutral positive => positive ==> 0.25 I second that. I wish it rained more where I am
# ?
# sadness neutral => neutral ==> 0.22812500000000002 early happy day of birth in case I don`t make it! Very tired from therapy today n just taking my medicine!  misshu! Love ya!
# ?
# neutral neutral => neutral ==> 0.0 **** it were is Eric or anyone else when you need your hair to be played with
# ?
# sadness negative => negative ==> 0.0 Allergies suck ducks nuts.     <=====8=====>
# ?
# neutral positive => positive ==> 0.7 Well it almost was a good day... Guess I just retry tomorrow
# ?
# love positive => positive ==> 0.7 sounds good. Appreciate the suggestion. Been a week now and we`re still offline  Time to ask for a refund...
# ?
# worry neutral => neutral ==> 0.5 He died.  Wait, what about Magic Jack? I just read it.
# ?
# hate negative => negative ==> 0.0 youstinkatrespondingtotexts!
# ?
# neutral negative => negative ==> -0.09999999999999999 well I ran out of beer so I left. Not sure about the ETA. Waiting waiting waiting. Bleh  Gonna be a long nite methinks.
# ?
# neutral positive => positive ==> 0.5 claire  love the show, got into the office @ 5am and no radio
# ?
# love neutral => neutral ==> 0.5 Pats in philly at 2 am. I love it. Mmm cheesesteak.  Miss my boyfriend   but I love vacation.
# ?
# sadness negative => negative ==> 0.2857142857142857 *sigh* I`m going to bed... I just don`t feel right anymore...
# ?
# neutral neutral => neutral ==> 0.19999999999999998 What? I focused on Tom so much I didn`t see my beloved Barack! Oh no! I must vote for both! Poor president only has 626 votes.
# ?
# sadness negative => negative ==> 0.0 Just cross `cause I`m stuck twiddling my thumbs now, ugh
# ?
# neutral neutral => neutral ==> 0.0 miss 16`th
# ?
# neutral neutral => neutral ==> -0.05 I know. But like I said, I have no idea how long it takes for them to investigate this stuff.
# ?
# worry negative => negative ==> 0.0 I cant sleep, but im too sore to move
# ?
# neutral negative => negative ==> 0.0 http://twitpic.com/4phze - Awe! I miss my baby
# ?
# empty negative => negative ==> 0.0 just answered you- never learned how to write in French- just basic stuff-
# ?
# neutral neutral => neutral ==> 0.0 what is it with chocolates? i just can never say no
# ?
# worry neutral => neutral ==> -0.2818181818181818 Achieving a new appreciation on how a xml build script can really be painful and cumbersome
# ?
# neutral neutral => neutral ==> -0.5 _radio i`m too awake now  ill have a nap this afternoon
# ?
# worry neutral => neutral ==> 0.0 i cant do anything
# ?
# neutral neutral => neutral ==> 0.0 still needs another 6 hours of sleep
# ?
# relief neutral => neutral ==> 0.0 I`m at work
# ?
# fun positive => positive ==> 0.8 RIP leonardo. You were a great mini fiddler crab
# ?
# neutral neutral => neutral ==> 0.1 Morning tweeple,way to early again
# ?
# sadness negative => negative ==> -0.25 Last day working for the Uni today, sad times
# ?
# love positive => positive ==> 0.15000000000000002 thanks neemah. I`m gonna be soooo close to you and izzy, yet so far
# ?
# worry negative => negative ==> -0.8749999999999998 My head hurts so bad I could scream!
# ?
# worry negative => negative ==> -0.03787878787878788 New work wellness challenge not going well.  I committed to not check email between 10 pm and 6 am.  Failed on first day.  Twice
# ?
# worry negative => negative ==> -0.37121212121212127 New blog post: [Blog] auto insuran...: I just found that my auto insurance policy had been expired. ( I am too careless  ...) .. Meanw ...
# ?
# neutral neutral => neutral ==> 0.0 where are all ma bestfriends at ? , MIA or wat ?
# ?
# worry neutral => neutral ==> 0.390625 oh men!!!!!!......I really can`t see my face........c`mon guys!!!
# ?
# worry neutral => neutral ==> 0.0 my sole supporter is not my sole supporter
# ?
# hate negative => negative ==> -0.4 don`t you hate it when you finish all your work and there`s still 1.25 hours left of work time
# ?
# sadness negative => negative ==> 0.0 is still missing her husband.    I really want him home.
# ?
# surprise neutral => neutral ==> 0.0 2 days of this month left, and I only have 400MB left on my onpeak downloads.
# ?
# fun positive => positive ==> 0.6000000000000001 Up is out?  I didn`t get the memo   It looks amazing.
# ?
# sadness negative => negative ==> -0.225 yearling in pet home died... very sad for their whole family
# ?
# neutral neutral => neutral ==> -0.15 fun in the sun hmmm hell no it`s cold
# ?
# worry negative => negative ==> -0.5 is feeling sad... for some reason..  http://plurk.com/p/wxji3
# ?
# sadness negative => negative ==> -0.27840909090909094 just uploaded my new blog... a painful story about an 80s year old man who cried because he wanted to die... very sad
# ?
# neutral neutral => neutral ==> 0.0 Hi...!!! Who is Mary Poppins???
# ?
# worry negative => negative ==> 0.6 Its so addicting, but its kind of a curse to do them at night time. Everytime i do one, i feel like making music afterwards
# ?
# neutral neutral => neutral ==> -0.3499999999999999 my last tweet didn`t send  bad phone
# ?
# fun neutral => neutral ==> -0.2009375 OMG Ur alive!!! LOL  2day has gone sooo slow  I`m going insane Grrr You doing anything tonight?
# ?
# empty negative => negative ==> 0.0 Have a headache  I`m going to bed. Goodnight!
# ?
# neutral neutral => neutral ==> 0.0 I was watching Parental Control
# ?
# fun positive => positive ==> 1.0 did you get them from california vintage? ahahah they have the BEST dresses, i want them but i dont have ebay
# ?
# worry neutral => neutral ==> 0.0 it wont let me
# ?
# sadness negative => negative ==> 0.24285714285714285 Took a shift tomorrow.    I don`t really feel like working right now.
# ?
# sadness negative => negative ==> 0.0 but now i have no money for a phone
# ?
# worry neutral => neutral ==> -0.05 Spent last night in A&E (ER). Wife tangled wheels with Daughter & hit the deck. Dislocation & fracture resulted.
# ?
# worry positive => positive ==> 0.2 9 days  I`m about ready to visit Torchwood and see if they`ve heard anything
# ?
# surprise negative => negative ==> 0.0 _morley where are you? In Bris? I can`t hear any thunder
# ?
# surprise neutral => neutral ==> -0.625 bec vs fat food   --- winner = fat food  but not this weeknend, ill beat it!
# ?
# sadness negative => negative ==> -0.39999999999999997 Too bad the Red Devils.. disappointing to say the least
# ?
# surprise neutral => neutral ==> 0.25 I had a dream about a pretty pretty beach and there was no beach when I woke up
# ?
# sadness negative => negative ==> -0.05 Have a 3ware 9650SE, not fast enough for 3x X25-M SSD RAID5. 800Mhz IOP on the HPT. Might try an Adaptec 5405 (1.2Ghz).
# ?
# worry negative => negative ==> -0.5 Ate Mandy, please forgive me. I really am sorry. I don`t wanna lose my Bff
# ?
# hate positive => positive ==> 0.475 Umm yeah. That`s probably a pretty good note to self because eeeeeewwwwwwww.
# ?
# worry negative => negative ==> -0.5 why are plane tickets so expensive
# ?
# worry negative => negative ==> -1.0 Needs a job BADLY!!!
# ?
# sadness negative => negative ==> 0.0 daaammmnnnnn I do wish I was there.
# ?
# worry neutral => neutral ==> 0.0 Went to Di Bella coffee roasters today and asked for a job...   The person I needed to speak to is on holiday...  #fb
# ?
# sadness neutral => neutral ==> -0.125 _hime I played up until the latter parts of the voodoo village part co-op until I lost my usual partner
# ?
# empty negative => negative ==> -0.5 Nite. Now I`m up n bored as opposed to almost sleep frm b 4
# ?
# neutral neutral => neutral ==> 0.0 guess its a no go girlie. I`m still at the gym and work at 6:30am
# ?
# love negative => negative ==> -0.4 i missed the game
# ?
# hate negative => negative ==> -0.08333333333333334 cuz airlines are super lame.
# ?
# sadness negative => negative ==> 0.0 I`m sorry to hear that. Here is my optimist: Things will get better. For all of us.
# ?
# relief negative => negative ==> 0.0 is done painting all the bedroom furniture, I still have to do the table but it will wait until after the move. Uggh moving in the heat
# ?
# neutral neutral => neutral ==> -0.08518518518518518 A hungry fool. Ill probably never see that Krispy Kreme again. Had to enjoy it. They closing down
# ?
# neutral neutral => neutral ==> 0.3 Looking for desktop twitter app that will actually let you access URLs, any suggestions? I liked Twittle but no linking
# ?
# worry negative => negative ==> 0.0 people in my house do not know how to close doors
# ?
# surprise neutral => neutral ==> 0.0 Why am I completing facebook quizzes at this time of the morning... especially a friday morning
# ?
# neutral negative => negative ==> 0.0 out with  &  i am soooo hungry
# ?
# worry negative => negative ==> 0.0 I don`t like the possibility of the left side of my brain hurting because of the thing called a VP shunt and possible death
# ?
# sadness neutral => neutral ==> 0.0 But yeah...I`m sad about my 'Ravenclaw' account. I love that account to bits.
# ?
# worry neutral => neutral ==> 0.625 @__sugar oh no  i am always here ;) <3
# ?
# neutral neutral => neutral ==> 0.0 @ poll : was trying to get it to work in a powerpoint to no avail.
# ?
# happiness neutral => neutral ==> 0.5 took a math test today. The day before the test, the teacher says bring your calculator. Luke was confident. Teacher decided no calcs.
# ?
# worry negative => negative ==> -0.16666666666666666 i think the vog is making me sicker than i think. feeling slightly achy
# ?
# empty neutral => neutral ==> 0.8 i was watching Harpers Island, lol... there was no vodka involved
# ?
# worry negative => negative ==> -0.5 i am doing homework it sux big time maths is the worst!!!!!!
# ?
# neutral neutral => neutral ==> 0.5 would have been better, IMO, if it let you play through all 3 songs provided. I just start to 'get it' and it blacks out.
# ?
# neutral negative => negative ==> 0.0 #3wordsaftersex it never started...
# ?
# sadness neutral => neutral ==> 0.0 sometimes i wish things could go back to the way they were the beginning of last summer
# ?
# empty neutral => neutral ==> 0.0 Trudy`s off Burnet...the one up north that no one goes to
# ?
# sadness neutral => neutral ==> 0.0 I feel the same way, but I guess no matter where you are there will always be memes.
# ?
# happiness neutral => neutral ==> 0.5 I Can`t do 30 minutes of Treadmill  but done 30 minutes for today already, gonna do 20 minutes more
# ?
# worry neutral => neutral ==> 0.0 Work day 7 of 7,
# ?
# happiness neutral => neutral ==> 0.0 Chillin with the roomies. Can`t wait for the zombie CLWN CR. Its gonna be 6-8 weeks
# ?
# neutral positive => positive ==> 0.38 I looove guitars, and playing them. I think they sound magnificent. If only i was better... If only
# ?
# neutral negative => negative ==> 0.8 no im not  cries LOL
# ?
# surprise neutral => neutral ==> 0.0 EpiCentre Wheelock Place, 250 units & for tourists only. Starting today
# ?
# neutral neutral => neutral ==> 0.0 Come on Knight... It`s been well over 4 hours
# ?
# worry neutral => neutral ==> 0.016666666666666677 not super keen on the drive home through the rain.. additional concentration required that i don`t really wanna deal with
# ?
# surprise negative => negative ==> -0.5 aw u can`t let me in on the secret!
# ?
# surprise neutral => neutral ==> -0.4 Im sorry  I don`t think I stick out, at least compared to what I used to look like.
# ?
# hate negative => negative ==> -0.24223958333333337 i HATE when i see pregnant women smokinggg!!!! its sooo irresponsible n selfish! its saaad. ultimately, the baby is the one who suffers.
# ?
# hate negative => negative ==> 0.0 Lies...lies...lies....you just cant avoid to lie about practically...EVERYTHING!
# ?
# neutral neutral => neutral ==> 0.0 twittascope is NOT rocking my socks - go away already!!
# ?
# neutral neutral => neutral ==> 0.0 Driving Back home because I forgot the piece of cake for _era
# ?
# worry neutral => neutral ==> 0.0 so I tried jumping without the trampoline and its like thud* thud*  shouldn`t have eaten that cookie.  http://myloc.me/1XIz
# ?
# sadness neutral => neutral ==> 0.8 Everytime I send an email to my coach, I feel a need to practice.   **** balls.  Lol
# ?
# sadness negative => negative ==> 0.0 It`s pissing me off and not letting me follow ericka
# ?
# sadness neutral => neutral ==> 0.425 Is going to sleep not peaceful  wanted to hear him say Good Night but that didn`t happen  Good Night everyone....
# ?
# sadness neutral => neutral ==> -0.25 my mums trying to make me feel ebtter about stopping voting adn not winning shortstack. i almost cried.
# ?
# neutral negative => negative ==> -0.3 i was so close to the tacos...one spot too late
# ?
# surprise neutral => neutral ==> 0.2 is thinking so much and i`m at work
# ?
# worry neutral => neutral ==> 0.13636363636363635 I have forgot the live with the Jonas Brothers on Facebook
# ?
# sadness negative => negative ==> 0.25 I haven`t seen Muffin in two whole days!
# ?
# sadness negative => negative ==> 0.0 i`ll miss y`all back... give  my regards...
# ?
# worry negative => negative ==> 0.0 I have to admit, I`m a bit bummed out that I wasn`t with my friends walking today....
# ?
# neutral positive => positive ==> 0.2952380952380953 girl a blunt is soooooooo in my thoughts right now. I had an absolutly GREAT day with a few stressors...come home
# ?
# worry negative => negative ==> 0.0 my twitter has been hacked again
# ?
# neutral neutral => neutral ==> 0.13636363636363635 i wont have time to buy  and i need a new binder pa
# ?
# hate negative => negative ==> -0.24999999999999997 hahaha well its try its so ugly
# ?
# neutral neutral => neutral ==> -0.2916666666666667 25-man Ulduar is hard...
# ?
# worry negative => negative ==> 0.0 I don`t even want to know WHY you know about VHEMT, but don`t go - we`d miss you
# ?
# fun positive => positive ==> 0.65 That`s awesome! We have that this weekend too but I can`t go because I`m moving this Sat.  I should be a lot of fun though
# ?
# neutral neutral => neutral ==> 0.0 night night twitter world. [still cant believe the thomas thing  tomorrow`s gunna be FUN/SAD]
# ?
# surprise neutral => neutral ==> 0.0 _tah oh no.  *hugs*
# ?
# worry negative => negative ==> 0.1 OMG-ness it`s 11:18 pm and I need to beup early to set up my garage sale it starts a 8am, wish I said 9am. I`m beat.
# ?
# happiness negative => negative ==> 0.0 i kno i doooo!!!!!!!!!! yall partyin with out me
# ?
# neutral neutral => neutral ==> 0.5 ugh.. my dad just told me to read an article about Kavya Shivashankar the spellin bee girl..and be more like her.
# ?
# worry neutral => neutral ==> 1.0 Decided that no matter how good my hair looks curly it doesn`t justify the burn I get from the curler! My hands covered  I suck at it!
# ?
# sadness negative => negative ==> 0.0 Going to sleep. Gonna fall asleep playing apps again. Tmrw is going to suck
# ?
# hate negative => negative ==> -0.4 I hate when my bf beats da dogs. But I guess that the only way to teach these pitts.
# ?
# worry negative => negative ==> -0.8749999999999998 sprained my ankle  like really badly and tore some stuffs. it hurts! and its my birthday weekend
# ?
# hate negative => negative ==> -1.0 think i may have broke a toe at the bar tonight......thanks drunk girl for steppin all over me!!!!!
# ?
# sadness neutral => neutral ==> 0.016666666666666663 I wish I had Left 4 Dead. But first I`d need something to play it on...
# ?
# neutral neutral => neutral ==> 0.0 me too
# ?
# neutral neutral => neutral ==> 0.0 that story reminds of living in Portugal
# ?
# hate neutral => neutral ==> 0.0 my roommate _tickle loves to ignore me
# ?
# neutral neutral => neutral ==> 0.5 I`ll make him nachos tomorrow. Better than if he would have made them himself.
# ?
# neutral neutral => neutral ==> 0.0 yeahhh. &dont judge my pillow
# ?
# relief positive => positive ==> 0.0875 Scary lightning and thunder  I`m glad it`s over now. Going to sleep, I hope I`m not late to school tomorow again. Haha
# ?
# sadness negative => negative ==> 0.0 my teeth and head hurts
# ?
# hate neutral => neutral ==> 0.0 Maths and Science were the strongest for me i think..dunno bout geography, only did like 1 day of study for 1/2 a year of work!
# ?
# boredom neutral => neutral ==> 0.0 Waiting in line @ tryst
# ?
# worry neutral => neutral ==> -0.9765625 Hope I get a job cuz we need an apartment. I`m drunk & miss my lil punkin  TEHE!!!
# ?
# worry neutral => neutral ==> 0.0 just got home! not wanting to read the last chaper of breaking dawn cause i dont want it to beover
# ?
# worry negative => negative ==> 0.0 Hanging out with sam, billy, and veronica. not going to school tomorrow to take sam to body shops. Dang car accidents
# ?
# sadness negative => negative ==> -0.375 no more arrested development. i am sad.
# ?
# neutral negative => negative ==> 0.0 _xo  wicked , what time you leaving? how come you cant stay the night
# ?
# sadness neutral => neutral ==> 0.08409090909090909 im contacting PAWS Philippines so i can find 'tiger' a new owner. im so sad. i love my dog soo much
# ?
# sadness negative => negative ==> 0.0 just got home! not wanting to read the last chaper of breaking dawn cause i dont want it to be over
# ?
# neutral negative => negative ==> 0.0 _babsi there`s a manual process... but it`s taking 4ever on my outlook database... pffff. crappy msft product
# ?
# sadness neutral => neutral ==> -0.1 Fuuudge. Movie store is closed
# ?
# hate positive => positive ==> 0.4625 Hahahaha! It`s not horrible, if others were singing with I`m sure it could work. I wish I could afford my own drum set
# ?
# worry neutral => neutral ==> 0.25 Am trying to get through the pilot of the first season of friday night lights. Oh gosh  Pass the tissue...
# ?
# sadness neutral => neutral ==> 0.0 Aw where are you headed to? i just cancelled my trip to Aussie
# ?
# worry negative => negative ==> 0.0 I have cystic lacrimal infectection?? my eye and face are swollen and it hurts!!
# ?
# worry neutral => neutral ==> 0.0 I didn`t think anyone caught that
# ?
# empty neutral => neutral ==> -0.4 I need to be sleeping.. But i`m not even tired..
# ?
# neutral negative => negative ==> 0.0 OH NEVERMIND I THINK THIS THING IS UNSALVAGEABLE
# ?
# sadness negative => negative ==> 0.7 I dont feel good AT ALL. fuckkk
# ?
# boredom neutral => neutral ==> 0.0 why did i agree to work a double shift
# ?
# worry negative => negative ==> -0.625 Ohh poor girl  I`ll email her... I am relying on you being here in October Mr!!
# ?
# neutral neutral => neutral ==> 0.0 When will Medhurst play again?
# ?
# worry negative => negative ==> -0.6999999999999998 bad times?
# ?
# hate negative => negative ==> 0.13636363636363635 aarrgghh - fu*k.....a hose has leaked water all over the new floating floor
# ?
# neutral neutral => neutral ==> 0.0 I`m a bit Ben`s Thai-ed out
# ?
# happiness neutral => neutral ==> 0.0 english class! working on interactive orals
# ?
# worry neutral => neutral ==> 0.0 Thank you for the rec but that doesn`t work
# ?
# worry positive => positive ==> 0.05000000000000001 My puppy Gizmo h8s me..  haha. He still growls @ me.  I always look back @ my long pruple scar on my fingie
# ?
# neutral neutral => neutral ==> 0.0 in 7-11  w/o you
# ?
# neutral negative => negative ==> -0.04375 Yeah, plus it`s just a little too far to walk to Pinocchio`s for sushi
# ?
# sadness neutral => neutral ==> 0.09999999999999998 Taylor Swift and Joe Jonas looked really good together. I`m kinda sad they broke up.
# ?
# worry neutral => neutral ==> 0.0 Lady across the way had a miscarriage, say a prayer
# ?
# sadness neutral => neutral ==> 0.0 God I just want to sleep.
# ?
# sadness negative => negative ==> -0.15000000000000002 Found my book. Starting a real paper-bound journal tonight. Have an annoying zit above my lip. Makes me look like I have herpes
# ?
# hate neutral => neutral ==> -0.19999999999999993 RATT ROCKED NASHVILLE TONITE..ONE THING SUCKED, NO ENCORE!  LIKE IN THE 80`S THEY STILL HAVE A FUN SHOW. PEARCY HAS THAT HOTT BAD BOY LOOK
# ?
# worry negative => negative ==> -0.6999999999999998 is feeling bad  just got bad news about my Mum
# ?
# sadness neutral => neutral ==> 0.0 But but I dun wanna
# ?
# sadness negative => negative ==> -0.1166666666666667 **** girl I`m so down but ya gotta let me know so I can get my kit together & I got a flyer  Any next weekend? I'M DOWN!
# ?
# sadness negative => negative ==> -0.1732142857142857 dbl booooooo for being sick, flippin blows! ... bahaha i kno i dont have many friends on here either. i feel so lame  haha
# ?
# neutral neutral => neutral ==> 0.0 thats what i was thinking but the only time it`s gonna be on is 1 am!
# ?
# neutral neutral => neutral ==> 0.21000000000000002 Peeps still here. Fun times. Gotta sleep tho. Work in the A.M. Some cool, hot chicks here. But none as cool as ____________. Missing her
# ?
# worry neutral => neutral ==> 0.35714285714285715 vineri...nimic special sau probabil un alt weekend pierdut...
# ?
# neutral negative => negative ==> 0.0 Counting the hours of lost sunshine until the Weekend
# ?
# sadness neutral => neutral ==> 0.0 _jodie Um, I was thrown from `s van yesterday and had to be taken to the ER
# ?
# worry negative => negative ==> 0.13333333333333333 got to final table, but....went out third.  Don`t think I`ll be getting my free seat
# ?
# neutral neutral => neutral ==> 0.75 good morning work this morning gutted lol nevermind
# ?
# hate negative => negative ==> 0.0 I have to work in the morning while my friends get to party it up.....stupid bberry lite flashing red and I have no messages!
# ?
# happiness negative => negative ==> -0.32142857142857145 FB is boring   and i wanna sing RIGHT NOW..! *-*
# ?
# worry negative => negative ==> 0.0 Last day at work...Sick to the bone
# ?
# worry negative => negative ==> -0.05 i feel like I`m on house arrest.
# ?
# neutral neutral => neutral ==> 0.10416666666666666 love is like a war,,easy to begin, hard to end..fiuuhh...
# ?
# surprise neutral => neutral ==> 0.0 ur supposed to be in BK tho
# ?
# worry negative => negative ==> -0.3875 Did you know that there is a shortage of shells for crabs to use on the beach due to beach combers? It is very sad
# ?
# surprise neutral => neutral ==> 0.0 Oh no!  Nighty night.
# ?
# sadness negative => negative ==> -0.7999999999999999 my stupid tooooth hurts
# ?
# love positive => positive ==> 0.5 : love the song 'together'. that`s 'his' song for me...well i think it`s still is
# ?
# sadness negative => negative ==> -0.4 my computers broken and I broke my laptop so I had to use the phone  ahh still on he cause they **** up my order.
# ?
# neutral positive => positive ==> 0.4375 _Gable It`s good isn`****! Our holiday chalet is out of sight but look v similar to those ones. Going home again today
# ?
# worry negative => negative ==> -0.5 It`s a sad economy. Just heard of another friend losing their job.  so sad. But just a reminder that...
# ?
# worry negative => negative ==> -0.18749999999999994 I`m just starting to feel really panicky and anxious that something bad has happened cos it seems like it`s been ages
# ?
# worry negative => negative ==> 0.0 my dog ran awayyy
# ?
# hate negative => negative ==> -0.6999999999999998 _is_one84 Those suck so bad.
# ?
# worry neutral => neutral ==> -0.0875 I`m back. top molar extracted  swollen face, all numb.  But no more toothache or sinus pain.
# ?
# worry positive => positive ==> 0.7 does anyone know any good rap songs? i need to make a rap/fun cd and i have no idea  helllllpppp
# ?
# love neutral => neutral ==> 0.0 I want to go to Peru this summer ahhhhhhh! Hopefully! Yesyesyes! I miss it over there!!!
# ?
# empty neutral => neutral ==> 0.0 what happen to the maids of yours? Quit once again? ...
# ?
# sadness positive => positive ==> 0.375 I`m awake. Anybody else awake? Wish I lived in the US since all the fun happens when I`m asleep!
# ?
# sadness neutral => neutral ==> 0.11249999999999999 _J heehee. i love you! i am tired.
# ?
# worry negative => negative ==> -0.4 my mobile phone refuses to charge!!  either the battery is broken or the chargerrr ( booooo
# ?
# worry negative => negative ==> -0.6999999999999998 hmmm, I thought u were sleeping!! Too bad I can`t see those videos until tomorrow night.
# ?
# sadness negative => negative ==> 0.06666666666666667 how I wish my parents put me into a Chinese school when I was younger. Then, it`ll be so much easier for me to get a job...
# ?
# relief neutral => neutral ==> 0.05000000000000001 Yeah, physically moving too!  Apparently we`ll be reporting directly to Mr. Hayward...
# ?
# worry negative => negative ==> 0.0 jealous  it looks like schindler`s list in toronto
# ?
# neutral neutral => neutral ==> 0.0 what?! Come as you are!!! But erock just left  bah D:
# ?
# worry negative => negative ==> -0.049999999999999996 Nearly fell asleep, but was jolted out of bed by a massive panic attack and now I`m not sure if I can sleep at all.
# ?
# neutral neutral => neutral ==> 0.0 for the gays i only made 200 tonight
# ?
# sadness negative => negative ==> 0.25 if one people did any wrong, the world blames all the people over there, this is the great world which we are living in!  ****!
# ?
# surprise neutral => neutral ==> 0.13636363636363635 nope.  they are all sleeping cuz they live on the east coast.
# ?
# neutral negative => negative ==> 0.0972222222222222 I bet its cool down in SR, huh? It`s not here. I haven`t stopped sweating since noon when dad and I were packing
# ?
# sadness negative => negative ==> 0.0 : eww. dislike
# ?
# worry neutral => neutral ==> 0.7 Tactical mistake: going to the city library and buying milk. Who knew? OUCH OUCH OUCH. Maybe a good thing I didn`t try for uni.
# ?
# neutral positive => positive ==> 0.10000000000000002 decided 2 trans frm relaxed 2 natural hair but i wish my whole head looked like my roots.  Age of the instant gratification....
# ?
# neutral neutral => neutral ==> 0.0 needs to have an increase on her salary  http://plurk.com/p/wxluu
# ?
# worry negative => negative ==> 0.425 my stomach feels like it`s touching the ground..i`m SO full
# ?
# love negative => negative ==> 1.0 Pug just woke me from an incredible sleep!
# ?
# love positive => positive ==> 0.40616122159090906 i can`t wait to hear your new album. i`m sure will be amazing.please just replay to me  i love you so much!!!!
# ?
# worry negative => negative ==> 0.0062500000000000056 Sooo much work so little time
# ?
# sadness negative => negative ==> 0.0 missed iron chef
# ?
# enthusiasm positive => positive ==> 0.1277777777777778 i know ridiculous! we never got to hang out  i love chicago and want to go shopping... so a trip sounds like fun
# ?
# hate negative => negative ==> 0.0 hates the net. ayaw bumukas ng twitter.  http://plurk.com/p/wxlxs
# ?
# worry negative => negative ==> -0.19444444444444448 Ugh, my internet was down!
# ?
# surprise negative => negative ==> 0.2 omg i didnt tweet all that much today.... *sadness*
# ?
# worry negative => negative ==> 0.0 is feeling so giddy and wanna go home.
# ?
# neutral neutral => neutral ==> 0.0 the week just wasnt the same without an adam lambert performance!!!
# ?
# neutral negative => negative ==> 0.0 The link doesn`t work
# ?
# worry neutral => neutral ==> 0.0 Up and packing. Its the last day of youth camp
# ?
# neutral neutral => neutral ==> 0.0 GOSSIP GIRL, WHEN ARE YOU COMING BACK  ! chaceeeeeee..
# ?
# worry positive => positive ==> -0.10416666666666666 Somebody please save the polar bears!
# ?
# worry neutral => neutral ==> 0.0 guess im staying home tonight...no movie-ing for me
# ?
# worry neutral => neutral ==> -1.0 reminds me of the weather a month ago it was horrible  I hope all is well hugs
# ?
# sadness negative => negative ==> 0.0 I miss my mom..  'May angels lead you in'
# ?
# love neutral => neutral ==> -0.1 there`s really no android twitter app of Tweetie`s calibre
# ?
# hate negative => negative ==> -0.6 on jacksonville beach walking in the cold **** water   but have to work in the morning   ily <(`-`)>
# ?
# neutral neutral => neutral ==> 0.0 _d No, it`s not...
# ?
# sadness negative => negative ==> -0.3 Can`t sleep. Sucks. The one day i have to sleep in and i have to get up and go shopping with mom. Ugh.
# ?
# neutral positive => positive ==> 0.2857142857142857 well i just got home and its not on till tmw at 530p but with comcast its on right now  but i didnt miss it
# ?
# sadness neutral => neutral ==> 0.1952380952380952 Sleppytime. Really missing my godfather right now. Love you Wayne
# ?
# worry positive => positive ==> 0.0 hope ya sleepin well  guys still here
# ?
# fun negative => negative ==> 0.0 i should be finished.... but i`m not.  color drawing, here i come.
# ?
# sadness negative => negative ==> -0.4 Lakers, baby Lakers!! I`ll miss the game tmwr. I have to work  you`ll have to keep me posted please
# ?
# worry negative => negative ==> -0.18333333333333335 **** being drunk and hot sucks
# ?
# sadness negative => negative ==> 0.0 misses my baby.
# ?
# worry neutral => neutral ==> 0.0 is not sleeping because he has paperwork to do.
# ?
# worry negative => negative ==> -0.7142857142857143 Showered in ice-cold water. Sweating now. Means one thing: I`m sick
# ?
# worry neutral => neutral ==> 0.2857142857142857 midnight cry.. wish the person I wanted, wanted me right now
# ?
# neutral neutral => neutral ==> 0.5 I`ma need you to follow me real quick cause I can`t DM you
# ?
# sadness negative => negative ==> -0.4 I`m poorly and can`t sleep
# ?
# worry negative => negative ==> 0.5 Went to pole class. Feeling discouraged. I am hopeless when it cones to dancing or sexy moves or spreading my legs.
# ?
# worry negative => negative ==> -0.45 And these poor, unfortunate souls don`t appear to have any pants at all...  ? http://blip.fm/~78qvz
# ?
# worry neutral => neutral ==> 0.0 If I told you how often I wash my hair you would never speak to me again
# ?
# worry negative => negative ==> -0.5 Looks like another sleepless night dedicated to homework. Sorry in advance, Ms. Chapman.
# ?
# worry negative => negative ==> 0.0 http://twitpic.com/662vk -  WHY DO U LOT MOCK ME!!!
# ?
# worry neutral => neutral ==> 0.0 didnt say goodnight to you
# ?
# hate negative => negative ==> 0.2857142857142857 I am not a ****! damnit!  [sending you an e-mail right now btw]
# ?
# neutral neutral => neutral ==> 0.0 In the Hongkong International Airport. Has to wait for 3-4 hours for our next flight to Cebu.
# ?
# neutral negative => negative ==> 0.0 Can`t sleep and nothings on tv!!
# ?
# love neutral => neutral ==> 0.05416666666666666 The pics I just uploaded are the baby pics of my cats. Missy is now an adult and a pretty little kitty, but Batty is in kitten heaven now
# ?
# neutral negative => negative ==> -0.175 oh ... you`ve been superseeded?  not good enough
# ?
# sadness neutral => neutral ==> 0.13333333333333333 today we say goodbye to the second good friend in a week from dmp  but at least the sun is shinning and I`m definately NOT working this pm
# ?
# boredom negative => negative ==> -0.5 is really, really bored... I guess I will go to bed
# ?
# worry neutral => neutral ==> 0.0 _of_the_dead I met a stranger just 10 min ago. He was stalking me at the store
# ?
# surprise neutral => neutral ==> 0.0 tee we beefin....what was u supposed to do before leavin????
# ?
# sadness negative => negative ==> 0.3333333333333333 Sometimes the things you say hurt the ones you love most unintentionally.  And you can never ever take it back or fix it.
# ?
# neutral positive => positive ==> -0.3125 IIII know!!! and mean
# ?
# sadness negative => negative ==> 0.0 Having Fever  dont feel to work
# ?
# worry positive => positive ==> 0.0 Taking Horse Pills, hoping I can get some sleep tonight
# ?
# neutral positive => positive ==> 0.0 PGPM student from where? I myself was a PGPM student about 4 years back. I wish I could stay one
# ?
# sadness negative => negative ==> 0.0 Working from home today, my back is killing me  Doctor and then physio after later today.
# ?
# neutral positive => positive ==> 0.0 back to work.. with no distractions..
# ?
# happiness positive => positive ==> 0.296875 demi, just say hi to me and it`s enough. just replay to me please  love you so much!!!
# ?
# neutral neutral => neutral ==> 0.5 awwww  i never noticed this http://bit.ly/RConp
# ?
# neutral negative => negative ==> -0.125 First impression of Silverlight: sadly, based on what I saw today, it`s quite problematic
# ?
# worry positive => positive ==> -0.4 is desperatly hoping my dad takes me to vanessa`s game
# ?
# worry negative => negative ==> 0.0 _and_jay hi!  **** your job!
# ?
# sadness negative => negative ==> -0.1 Missing you all deeply
# ?
# happiness negative => negative ==> 0.03958333333333333 big now!!! Vanessa is going to be 3 in September, its going by so fast!  its hard cuz Im workin so much, I miss out on alot
# ?
# neutral neutral => neutral ==> 0.3333333333333333 _cheryl Lucky, now I want to teleport
# ?
# worry positive => positive ==> -0.10416666666666666 Somebody please save the polar bears!
# ?
# worry negative => negative ==> -0.875 My nose is runny, my head is pounding, and teeth hurt like a ****. MAN. @-) I feel awful.  =((
# ?
# relief positive => positive ==> 0.0 Headin home...Refreshed my mind and soul justa lil bit...Bac to reality.
# ?
# empty neutral => neutral ==> 0.0 wut do i do now????
# ?
# anger neutral => neutral ==> 0.0 Working   But it`s Fridaaaayyyyy
# ?
# worry positive => positive ==> -0.1 At the Grove for `Drag Me to Hell.` I hope that it doesn`t suck.
# ?
# worry negative => negative ==> 0.16666666666666666 so i feel like **** for saying HAPPY BELATED BIRFDAYY.. i`m only a month late
# ?
# neutral negative => negative ==> -0.4 FC is finally up again. it`s about time. i hate that this keeps happening
# ?
# neutral negative => negative ==> -0.09999999999999999 seriously bored without anyone to talk to... but not tired enough for sleep
# ?
# sadness negative => negative ==> -0.20833333333333334 bed bed bed  do you never answer texts anymore?  I thought of you the other day and sent one but never heard back. Sad day
# ?
# neutral neutral => neutral ==> 0.0 where u at?
# ?
# sadness neutral => neutral ==> 0.0 waah. We`re no longer your peeps.
# ?
# surprise neutral => neutral ==> 0.0 Extremly deep
# ?
# happiness neutral => neutral ==> 0.20625000000000004 My little foster kittens are getting big...chubba and Winston are going 2 b missed when they get amazing homes.
# ?
# enthusiasm neutral => neutral ==> 0.0 one week till exam block
# ?
# neutral neutral => neutral ==> 0.3571428571428571 _Yours13 I`m not at home with my cats right now!
# ?
# worry positive => positive ==> -0.3333333333333333 hoping i didn`t fail english. that would just be sad
# ?
# worry neutral => neutral ==> 0.29 Know what would be great? For my shoulder to stop hurting so I can sleep normal again.  I just want/need a few solid hours of good sleep.
# ?
# sadness negative => negative ==> -0.5999999999999999 I`m sorry about your bad driving experiences.
# ?
# neutral neutral => neutral ==> 0.0 i don`t have any of that
# ?
# hate negative => negative ==> 0.0 plan may changes , nooooooo
# ?
# hate negative => negative ==> 0.0 my sister is a douchebag
# ?
# neutral neutral => neutral ==> -0.5 Random has an a
# ?
# worry negative => negative ==> 0.0 I knew I should`ve worn the SARS mask on the plane from SoCal.. feeling the beginnings of a sore throat
# ?
# neutral negative => negative ==> -0.05 july... too long
# ?
# worry neutral => neutral ==> 0.4 awww I wish I could have been there  I`m stuck here about to jab out my eyes with knitting needles
# ?
# surprise neutral => neutral ==> 0.0 Me too.  Wonder if Mnet will show it...
# ?
# neutral negative => negative ==> 0.0 Wearing glasses gives me a headache.
# ?
# worry negative => negative ==> 0.0 finished sewing for the night, uploading pictures from slidebar and beach. i cant believe i am having difficulties with twitter!
# ?
# sadness neutral => neutral ==> -0.7142857142857143 thank you  (: cant wait!!!! ummm btw ima crash still sick
# ?
# worry negative => negative ==> 0.2 #liesgirlstell  a guy calls her phone to see if the number is real ) ohh my phone isn`t working . try tomorrow .
# ?
# neutral neutral => neutral ==> 0.0 But  is on page 6 at Ms Twitterworld, only 26 votes
# ?
# worry negative => negative ==> 0.35 I`m bummed that I can`t wear my sweet Nike kicks to work.
# ?
# neutral positive => positive ==> 0.4105034722222222 sleep....good night tweeties!!! down to OC tomorrow. I hope and pray that Rachyl gets better SOON!!!
# ?
# sadness negative => negative ==> -0.6 It`s depressing I`m stuck inside all day
# ?
# worry negative => negative ==> -0.75 I even saw the news feeds of the archie website. But can`t believe he`d choose veronica. I`m disappointed
# ?
# sadness negative => negative ==> -0.7571428571428571 i hate being sick. i miss   and
# ?
# neutral neutral => neutral ==> 0.0 im eating sliders at barjohnnys! (theyre pork tho not beef  still on the search...)
# ?
# happiness neutral => neutral ==> 0.04 Getting ready for school - second maths test today  also its my last day of 3rd year!! Next week i will officially be in 4th year
# ?
# sadness neutral => neutral ==> 0.0 Woke Up,I Wanna Stay In My bed
# ?
# worry negative => negative ==> 0.0 depressed that i wasn`t included in the morcom gardens quiz on facebook
# ?
# sadness negative => negative ==> 0.0 Upsidedown tomato plants died!
# ?
# worry neutral => neutral ==> 0.14583333333333334 Oh come on!!! You get next week off and I get next week full of exams!
# ?
# neutral negative => negative ==> -0.075 friday here at last, not much fun when your skint though
# ?
# sadness negative => negative ==> -0.025 Caan`t Iht Be Earlier? ICant Wait That Long.  Ahar. (:
# ?
# happiness positive => positive ==> 0.0 Friday yay!! And a bonus, don`t have to drive to Wales tonight.  Athough will miss kitten cuddles and going for a ride
# ?
# worry negative => negative ==> 0.0 My children have promised me birthday brekkie in bed. There`s a problem with that in that there`s bugger all food in the house
# ?
# worry neutral => neutral ==> 0.0 woops! I only just realized my DMs to you are not going through
# ?
# surprise negative => negative ==> -0.3 I cant use my blackberry today. This sucks.
# ?
# enthusiasm negative => negative ==> -0.125 Q: what studio created `Open Season`? should google it or look at the dvd downstairs but feeling lazy
# ?
# neutral neutral => neutral ==> 0.0 the times they are a changing
# ?
# sadness negative => negative ==> -1.0 why do you hate me!?
# ?
# hate negative => negative ==> -0.10000000000000003 time for tv in bed.Then spending all day catching up on studying  i hate online summer classes
# ?
# neutral neutral => neutral ==> -0.2 video is not available to us foreigners
# ?
# sadness negative => negative ==> -0.3 http://twitpic.com/663vr - Wanted to visit the animals but we were too late
# ?
# worry negative => negative ==> 0.0 PC I agree...  We have a problem. We must stop spending and only work!!!
# ?
# sadness negative => negative ==> 0.0 #jonaswebcast i just missed it!!!!
# ?
# hate negative => negative ==> 0.1708333333333333 Dang it! I REALLY look like ****!! Sigh only had 35mins to shower and 10mins to get ready
# ?
# sadness negative => negative ==> 0.0 So exhausted..can`t sleep. I don`t like these nights
# ?
# sadness positive => positive ==> 0.13068181818181818 i`m gonna miss all the live Comet action tomorrow! i have to go take care of my cousins and they don`t have access to the interwebz
# ?
# surprise positive => positive ==> 1.0 lol i cant drink!!
# ?
# ...
# ?
# fun positive => positive ==> 0.0 13:00 is kickoff. The red cars hopefully
# ?
# worry negative => negative ==> 0.0 i changed my mind dammit!! a Tsar can change his mind at any time without no prior notice
# ?
# relief positive => positive ==> 0.1 Morning all, finally got to stream media from PC to PS3 via wireless router, much easier than using a USB dongle, ah, techy simplicity.
# ?
# worry neutral => neutral ==> -0.2 Searching my home for a few things to cook them for dinner this evening. It`s mothers day so guess who im eating with
# ?
# neutral positive => positive ==> 0.0 i wish the birthday massacre would come to australia  i think they said they`re thinking about it though!!
# ?
# love positive => positive ==> 0.9 had a great time celebrating mother`s day  to me, being a mom is the best job on earth!
# ?
# love positive => positive ==> 0.5375 Almost, almost.. Thanks on the 'good save' Z!
# ?
# relief positive => positive ==> 0.3 juz donated books/mags 4 charity. Not only do I feel good but it gave me a good workout from all that heavy lifting
# ?
# happiness neutral => neutral ==> 0.0 last drops of the thesis... God let it end today.
# ?
# happiness positive => positive ==> 1.0 happy birthday!
# ?
# surprise neutral => neutral ==> 0.0 twitwoo! i can tweet from my phone
# ?
# worry neutral => neutral ==> 0.2 watching click, they are talkin about twitter and celebrityTweet  im just gonna get ready for work
# ?
# happiness positive => positive ==> 0.6 Defo can`t wait we will have a nice afternoon and some music
# ?
# sadness neutral => neutral ==> 0.3333333333333333 oh mann das ist super lustig  du armer... macs age 2 months, battery charging NO. garantiefall...
# ?
# sadness neutral => neutral ==> -0.05000000000000002 Home from Whitney`s. No sleep. Church in a bit. Dangggg....I`m tired. But it was worth it
# ?
# neutral positive => positive ==> 0.5 tell pete he looks sexy with a beard.
# ?
# happiness neutral => neutral ==> 0.0 is playing MYBRUTE!  follow me at: http://yhana09.mybrute.com
# ?
# neutral negative => negative ==> 0.0 sociology is done, english and biology left... i`m going to DIE
# ?
# happiness positive => positive ==> 0.2 this is really helpful,  you swear a lot, i just realized. haha.
# ?
# happiness positive => positive ==> 0.5722222222222223 OK. Happy to hear that you are feeling fine
# ?
# happiness positive => positive ==> 0.8 #firefly weekend on SciFi channel  I`m a happy man
# ?
# enthusiasm positive => positive ==> 0.8 Yes! That sounds like a great idea. Message me on LJ about it
# ?
# love positive => positive ==> 0.4 rt  #barcampbkk3 for entertainment at night, bring your favourite mp3s .. there should be a way we can enjoy music together
# ?
# neutral neutral => neutral ==> 0.0 in bed watching Rove
# ?
# happiness positive => positive ==> 0.0 Celebrating mother`s day with apple pie
# ?
# happiness positive => positive ==> 1.0 HAPPY MOTHER`S DAY LADIES!!! Hope you all have a wonderful day.
# ?
# worry negative => negative ==> -0.25 Actually, I also thought Mother`s Day was May 31st until I was remembered of Pentecost  Uselessly complicated, I would say
# ?
# relief positive => positive ==> 0.3 Smile. Everything worked out.
# ?
# surprise positive => positive ==> 0.5 Hello  ...hehe yup we sure do ...lovely to `see` you ****
# ?
# empty neutral => neutral ==> 0.0 Yeah *fingers crossed*
# ?
# worry neutral => neutral ==> 0.4166666666666667 Evening  Yorkshire`s warm but overcast. How`s NZ? Don`t tell me - dark lol
# ?
# surprise positive => positive ==> 0.37500000000000006 Sensation Ocean of White Portugal: absolutely amazing  Adoreiii!
# ?
# happiness neutral => neutral ==> 0.0 [-O] i wish the birthday massacre would come to australia  i think they said they`re thinking about it tho.. http://tinyurl.com/p6lfch
# ?
# worry neutral => neutral ==> 0.225 doing the andy dance  the one on fonzie gomez show ;) haha
# ?
# love neutral => neutral ==> 0.1 is freaking exhausted...need to go to bed....gotta get up early YUCK....HAPPY MOTHER`S DAY TO ALL YOU MOMMIES OUT THERE
# ?
# neutral neutral => neutral ==> 0.6083333333333334 lol fine, I go for her too
# ?
# neutral neutral => neutral ==> 0.2619047619047619 Star Trek? Me? Nah. My Dad is one for Star Trek right enough. Today, I`m off to see `Corlaine`. Much more my style Shezz.
# ?
# happiness neutral => neutral ==> 0.0 Well im hving another one today yey
# ?
# neutral neutral => neutral ==> 0.4 50 Kayla-lee, i think your the only one that knows what that number means lol  x
# ?
# love positive => positive ==> 0.8 Happy Mother`s day; God bless you & all mother`s worldwide; mother nature...  technology emotion in motion...
# ?
# love positive => positive ==> 0.8 Happy Mothers Day
# ?
# neutral positive => positive ==> 0.5 so glad i`m not at uni anymore
# ?
# fun neutral => neutral ==> 0.43333333333333335 ok Im off to pc world then  **** tweet u later **** lol
# ?
# neutral positive => positive ==> 0.0 says gud eve guys.. lets play poker yeah!! cant read my poker face  http://plurk.com/p/sw4yq
# ?
# surprise neutral => neutral ==> 0.0 Then I guess that makes me Dot?
# ?
# worry neutral => neutral ==> 0.34545454545454546 Whats your name: Adelaide-Marie How old r u: 14 Where Do u live: IN THE WORLD  lol i jk, canada(toronto)
# ?
# surprise positive => positive ==> -0.1875 her son is 7 and captured it outside...THANK GOD I HAVE A LITTLE GIRL
# ?
# love positive => positive ==> 0.46875 is so  just made a card 4 my mom!!   can`t wait to see the smile on her face when she see`s it!!
# ?
# neutral positive => positive ==> 0.5 would love to hear all of this from a Nokia perspective...
# ?
# fun neutral => neutral ==> 0.06666666666666667 haha, not always, just a 2-day-trip, for a friend. But I`ve been here some times. That`s why I know basic Japanese
# ?
# neutral neutral => neutral ==> 0.0 Sports Bar Shatranjanpoli Rest Ph 26498457 All Sports Bar Andheri W 26733333 Dont know whether that helps. Google ki jai ho
# ?
# sadness neutral => neutral ==> -0.07500000000000002 Man i hate church. Has to be done though. I like the way it makes other people feel good
# ?
# neutral neutral => neutral ==> 0.0 On what..
# ?
# neutral neutral => neutral ==> 0.0 _Hayward go two way mirrors
# ?
# love positive => positive ==> 0.1708333333333333 _dizon it`s a little late but congratulations, leah  happy mothers day!
# ?
# love positive => positive ==> 0.37500000000000006 Sensation Ocean of White Portugal: absolutely amazing  Adoreiii!
# ?
# fun neutral => neutral ==> 0.05 is it? :O im gonna get that
# ?
# neutral negative => negative ==> 0.25 Obama last night: 'Most of you covered me, all of you voted for me. Apologies to the Fox table.'       http://bit.ly/bGcnW
# ?
# worry negative => negative ==> 0.2130681818181818 indeed, we live a life on the edge of things, and one foot foul of the law!!
# ?
# neutral positive => positive ==> 0.5583333333333333 Well I *did* put in a good innings...sweared at the brother in law..was in fine form
# ?
# happiness neutral => neutral ==> 0.0 Home !! Home @ last !!!!! Time to step outside for some life
# ?
# love positive => positive ==> 0.0 _MC string out the dress.. Work that into a track please!!! What do u have coming up?? I`m ur biggest fan
# ?
# happiness positive => positive ==> 1.0 greeting you all a happy mother`s day!
# ?
# happiness positive => positive ==> 0.7 oh, a really good 1 dude, thx... added
# ?
# neutral neutral => neutral ==> 0.0 cook ; do you wanna measure my ****? its daddy-size.
# ?
# surprise positive => positive ==> 1.0 OMG!!! am luat examenul la SPSS! Me so happy!
# ?
# happiness positive => positive ==> 0.175 I`ve read about those. They`re cool. You should definitely get one
# ?
# sadness positive => positive ==> 0.8 Have a great day..... if the rain keeps up I may go swimming instead of dining here
# ?
# worry negative => negative ==> 0.0 _one Could use GarageBand though it`s probably overkill.
# ?
# neutral neutral => neutral ==> 0.0 is going to go get some food.
# ?
# enthusiasm positive => positive ==> 0.35 answer my really cool questions
# ?
# love positive => positive ==> 0.5 _Wesely he he   love it.
# ?
# worry neutral => neutral ==> 0.125 It takes nearly 2 days to figure out what causes the mic problems at #euruko: Do not hold the mic at the bottom!
# ?
# worry neutral => neutral ==> 0.05803571428571428 Luke M here, thanks Ps Chris! Ur husband is pretty cool I reckon! Sorry u were feeling sick and hope you feel better soon!
# ?
# neutral neutral => neutral ==> 0.018749999999999996 Up early so washed and waxed the car. I`m sure the neighbours think I`m mad, I wash it nearly every week.
# ?
# hate neutral => neutral ==> 0.35 yer, oh that`s **** cause u hell need to post more haha so we can talk
# ?
# happiness neutral => neutral ==> 0.0 Yep: http://bit.ly/15yyId  We go there for Christmas treats!
# ?
# happiness neutral => neutral ==> 0.0 WOOHOO!!!  My broom isnt up to standards....there is no seatbelt on mine....*whispers*  I like the Swiffer...
# ?
# happiness positive => positive ==> 1.0 happy mother`s day!
# ?
# happiness neutral => neutral ==> 0.0 watching Bolt with my brothers and my mom.
# ?
# love positive => positive ==> 0.8 happy mother`s day everyone
# ?
# relief positive => positive ==> 0.1875 Assignment actually looking pretty decent....so glad I changed my topic at the last minute
# ?
# love positive => positive ==> 0.6 thankies  no pictures in yet...but soon!! M`off to wash up love, have a good satdee ****
# ?
# love positive => positive ==> -0.48828125 http://twitpic.com/24mer - i like Mr Piggls I mean Pickles!!
# ?
# happiness positive => positive ==> 0.25 Thanks for making me laugh
# ?
# neutral positive => positive ==> 0.15000000000000002 ok2  g`nyt? Haha too early.
# ?
# love positive => positive ==> 0.625 I LOVE YOU GUYS! get your **** to australia in december for my birthday
# ?
# love positive => positive ==> 0.85 Happy Mother`s Day! It will be a good day
# ?
# happiness positive => positive ==> 0.0 instant-messaging with two of my favourite conversation guys
# ?
# love positive => positive ==> 0.75 Happy Mothers Day! allergies are ****. Oh and I hope Miller has a better day too
# ?
# fun negative => negative ==> 0.0625 8:30PM... it has just hit me i have school tomorrow :O ahaha! I`ll stay on til 9 i think  ****
# ?
# fun neutral => neutral ==> -0.2 on a sunny walk round the lake this morning we met a mother goose and father goose and five baby goslings
# ?
# love positive => positive ==> 0.5 happy mothers day to all the mothers, grandmothers, furbaby mommies, etc!  heading out for breakfast with my mom shortly
# ?
# love positive => positive ==> 0.5 I love to Read  And i love Film making
# ?
# worry negative => negative ==> -0.3 hey! negative on the primatech, this handle`s been on the tubes for a decade longer than heroes has
# ?
# sadness negative => negative ==> -0.026041666666666685 haha! And Twitter! Hard though isn`****?!
# ?
# happiness positive => positive ==> 0.2 Thanks for the follow man
# ?
# worry positive => positive ==> 0.13333333333333333 sure. But be careful also of making statements that we don`t do it. Parallel ideas do happen. I`ve seen it myself.
# ?
# surprise neutral => neutral ==> -0.25 anychance you can get matthew to give a shout out to my mum Sarah for mothers day! we saw 'Ghosts from girlfriends past today'
# ?
# love positive => positive ==> 0.8 Happy Mother`s Day to all my twitter moms (including myself)
# ?
# love positive => positive ==> 0.8 goooodnight everyone!  and Happy Mothers Day to all the mothers out there.
# ?
# love positive => positive ==> 1.0 Happy Mother`s Day to all the moms out there!
# ?
# neutral neutral => neutral ==> 0.0 I made a MySpace for Twitter with the name 'The Twitter Kingdom'. Here is the link: http://bit.ly/13PQtw  - join me!
# ?
# surprise positive => positive ==> 0.0 Oh aye.....he rocks, shes ****
# ?
# enthusiasm positive => positive ==> 0.2333333333333333 whaatttaatttt! she is a good cook and really creative, silly sierra
# ?
# happiness positive => positive ==> 0.9 _bach daps were the best lol
# ?
# happiness neutral => neutral ==> 0.2 haha i will remember that  ****
# ?
# happiness positive => positive ==> 0.6000000000000001 ME TOO! please come online *-* hope you`ve had an amazing weekend
# ?
# neutral negative => negative ==> 0.05 No, a-ha is unfortunatelly from Norway. We have a big family happening and therefore we need some old hits
# ?
# surprise positive => positive ==> 0.5 today was interesting...
# ?
# worry neutral => neutral ==> 0.0 How Do You Sleep - Jesse McCartney
# ?
# enthusiasm positive => positive ==> 0.6 BEEN TOWN WITH THE MOTHER  NICE & SUNNNY
# ?
# relief positive => positive ==> -0.2 Gooood party last night (: Although I am extremely tired now. xD Off to bed to lounge around watch tv and sleep all day
# ?
# happiness positive => positive ==> 0.125 Wow! Up, coffee in hand and already outside.  So peaceful on Sunday mornings.
# ?
# love positive => positive ==> 0.6 Happy Mothers Day, Mum.. Love you lots   1 month and 11 days to go.. AND 1 month to go for ma bby  love you Bash
# ?
# happiness neutral => neutral ==> 0.0 THE VIDEO IS FINALLY DONE WOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO!
# ?
# happiness positive => positive ==> 0.6 Watched Wolverine yesterday ... a spur of the moment kinda thing. Awesome! So proud that a South African director did that
# ?
# sadness neutral => neutral ==> 0.7 is heading off to the fair
# ?
# happiness positive => positive ==> 1.0 the sunset view is SO beautiful from my room!
# ?
# happiness positive => positive ==> 0.3833333333333333 Very well thank you! How are you, more importantly?
# ?
# happiness neutral => neutral ==> 0.8 EH! u dont like retro? tisk tisk, what u been upto? ...apart from waxing ur 'mustache' lol
# ?
# love positive => positive ==> 0.8 happy birthday
# ?
# happiness positive => positive ==> 0.875 good luck chan! gue kmrn bawa backpack kosong, quite helping
# ?
# fun positive => positive ==> 1.0 good morning/midday nation!  FORMULA ONE IN ONE HOUR!
# ?
# love positive => positive ==> 0.4166666666666667 to my pretty lady  HAPPY MOTHER`S DAY!!! She`s the mother of my future son-in-laws
# ?
# empty neutral => neutral ==> -0.2 Or even listen to Susan`s green policies
# ?
# neutral neutral => neutral ==> 0.2857142857142857 right. coursework now. PROMISE
# ?
# worry negative => negative ==> -0.26666666666666666 bloody Feds, they lost last statement and r hounding me for another one. I dodged them one last week
# ?
# surprise positive => positive ==> 1.0 awesome. Wha`dya get her?
# ?
# happiness positive => positive ==> 0.0 Sitting in Gatwick- going home for a week! cant wait to see family
# ?
# happiness positive => positive ==> 0.7 good luck with your auction
# ?
# surprise neutral => neutral ==> 0.0 Oh that`s why.
# ?
# happiness neutral => neutral ==> 0.875 husband is golfing & the Toddler and I shall frolic. Am I the consummate mama in that Im so happy with my day?
# ?
# happiness positive => positive ==> 0.0 going to watch boy in the striped pj`s hope i don`t cry
# ?
# happiness positive => positive ==> 0.875 gave the bikes a thorough wash, degrease it and grease it. think i did a really good job!
# ?
# happiness positive => positive ==> 0.375 had SUCH and AMAZING time last night, McFly were INCREDIBLE
# ?
# love neutral => neutral ==> 0.23095238095238094 His snoring is so annoying n it keeps me from sleeping (like right now, lol) but I honestly wud miss it if it eva left  I love him.
# ?
# neutral neutral => neutral ==> 0.0 can you give me the link for the kimba diaries please?
# ?
# neutral positive => positive ==> 0.4 Ooo showing of your French skills!! lol Things good over here. Lovely weather, so should be outside  How`s u?
# ?
# neutral neutral => neutral ==> 0.0 nan
# ?
# love positive => positive ==> 0.65 Happy Mothers Day  All my love
# ?
# love positive => positive ==> 0.36875 Happy Mother`s Day to all the mommies out there, be you woman or man as long as you`re `momma` to someone this is your day!
# ?
# happiness neutral => neutral ==> 0.6065340909090909 WASSUP BEAUTIFUL!!! FOLLOW ME!!  PEEP OUT MY NEW HIT SINGLES WWW.MYSPACE.COM/IPSOHOT I DEF. WAT U IN THE VIDEO!!
# ?
# love neutral => neutral ==> 0.0 bullet train from tokyo    the gf and i have been visiting japan since thursday  vacation/sightseeing    gaijin godzilla

# %%
sent_tup
# Out:
# {('anger', 'negative', 'negative'),
#  ('anger', 'neutral', 'neutral'),
#  ('anger', 'positive', 'positive'),
#  ('boredom', 'negative', 'negative'),
#  ('boredom', 'neutral', 'neutral'),
#  ('boredom', 'positive', 'positive'),
#  ('empty', 'negative', 'negative'),
#  ('empty', 'neutral', 'neutral'),
#  ('empty', 'positive', 'positive'),
#  ('enthusiasm', 'negative', 'negative'),
#  ('enthusiasm', 'neutral', 'neutral'),
#  ('enthusiasm', 'positive', 'positive'),
#  ('enthusiasm', 'positive', nan),
#  ('fun', 'negative', 'negative'),
#  ('fun', 'neutral', 'neutral'),
#  ('fun', 'positive', 'positive'),
#  ('happiness', 'negative', 'negative'),
#  ('happiness', 'neutral', 'neutral'),
#  ('happiness', 'positive', 'positive'),
#  ('happiness', 'positive', nan),
#  ('hate', 'negative', 'negative'),
#  ('hate', 'neutral', 'neutral'),
#  ('hate', 'positive', 'positive'),
#  ('love', 'negative', 'negative'),
#  ('love', 'neutral', 'neutral'),
#  ('love', 'positive', 'positive'),
#  ('love', 'positive', nan),
#  ('neutral', 'negative', 'negative'),
#  ('neutral', 'neutral', 'neutral'),
#  ('neutral', 'neutral', 'positive'),
#  ('neutral', 'neutral', nan),
#  ('neutral', 'positive', 'positive'),
#  ('neutral', 'positive', nan),
#  ('relief', 'negative', 'negative'),
#  ('relief', 'neutral', 'neutral'),
#  ('relief', 'positive', 'positive'),
#  ('sadness', 'negative', 'negative'),
#  ('sadness', 'negative', nan),
#  ('sadness', 'neutral', 'neutral'),
#  ('sadness', 'positive', 'positive'),
#  ('surprise', 'negative', 'negative'),
#  ('surprise', 'neutral', 'neutral'),
#  ('surprise', 'positive', 'positive'),
#  ('worry', 'negative', 'negative'),
#  ('worry', 'negative', 'neutral'),
#  ('worry', 'negative', nan),
#  ('worry', 'neutral', 'neutral'),
#  ('worry', 'neutral', 'positive'),
#  ('worry', 'positive', 'negative'),
#  ('worry', 'positive', 'neutral'),
#  ('worry', 'positive', 'positive'),
#  ('worry', 'positive', nan)}

# %%
train_data
# Out:
#            textID   sentiment         author  \
# 1      1956967666     sadness      wannamama
# 2      1956967696     sadness      coolfunky
# 3      1956967789  enthusiasm    czareaquino
# 4      1956968416     neutral      xkilljoyx
# 5      1956968477       worry  xxxPEACHESxxx
# ...           ...         ...            ...
# 39995  1753918954     neutral  showMe_Heaven
# 39996  1753919001        love       drapeaux
# 39997  1753919005        love       JenniRox
# 39998  1753919043   happiness       ipdaman1
# 39999  1753919049        love    Alpharalpha
#
#                                                     text  \
# 1      Layin n bed with a headache  ughhhh...waitin o...
# 2                    Funeral ceremony...gloomy friday...
# 3                   wants to hang out with friends SOON!
# 4      We want to trade with someone who has Houston ...
# 5      Re-pinging : why didn`t you go to prom? BC my ...
# ...                                                  ...
# 39995                                                nan
# 39996                     Happy Mothers Day  All my love
# 39997  Happy Mother`s Day to all the mommies out ther...
# 39998  WASSUP BEAUTIFUL!!! FOLLOW ME!!  PEEP OUT MY N...
# 39999  bullet train from tokyo    the gf and i have b...
#
#                                                 old_text       aux_id  \
# 1      Layin n bed with a headache  ughhhh...waitin o...   c811396dc2
# 2                    Funeral ceremony...gloomy friday...   9063631ab1
# 3                   wants to hang out with friends SOON!   2a815f151d
# 4      @dannycastillo We want to trade with someone w...   82565a56d3
# 5      Re-pinging @ghostridah14: why didn't you go to...   a610d6b25b
# ...                                                  ...          ...
# 39995                                   @JohnLloydTaylor  p1000008985
# 39996                     Happy Mothers Day  All my love   0b62ea4f2d
# 39997  Happy Mother's Day to all the mommies out ther...   1adaa3519d
# 39998  @niariley WASSUP BEAUTIFUL!!! FOLLOW ME!!  PEE...   d63253be9a
# 39999  @mopedronin bullet train from tokyo    the gf ...   879f64f30d
#
#       new_sentiment                                      selected_text
# 1          negative                                           headache
# 2          negative                                             gloomy
# 3          positive               wants to hang out with friends SOON!
# 4           neutral  We want to trade with someone who has Houston ...
# 5          negative                                     didn`t like my
# ...             ...                                                ...
# 39995       neutral                                                nan
# 39996      positive                                              Happy
# 39997      positive                                 Happy Mother`s Day
# 39998       neutral  WASSUP BEAUTIFUL!!! FOLLOW ME!!  PEEP OUT MY N...
# 39999       neutral  bullet train from tokyo    the gf and i have b...
#
# [39173 rows x 8 columns]

# %%
train_data.sentiment.unique()
# Out:
# array(['sadness', 'enthusiasm', 'neutral', 'worry', 'surprise', 'love',
#        'fun', 'hate', 'happiness', 'boredom', 'relief', 'anger'],
#       dtype=object)

# %%
neg = 'negative'
pos = 'positive'
neu = 'neutral'

sent_map = {
    'sadness': neg,
    'enthusiasm': pos,
    'neutral': neu,
    'worry': neg,
    'surprise': pos,
    'love': pos,
    'fun': pos,
    'hate': neg,
    'happiness':pos,
    'boredom': neg,
    'relief': pos,
    'anger': pos,
}

# %% [markdown]
# ## nltk.sentiment.vader를 이용한 수도 라벨링
# - https://www.nltk.org/howto/sentiment.html

# %%
import re
import nltk
import heapq
import string

from nltk.sentiment.vader import SentimentIntensityAnalyzer

sid = SentimentIntensityAnalyzer()

def ext_sent_word(text, sentiment, topk=2, verbose=False):
    word_list = []
    sen_list = []
    score_list = []
    
    splited_text = text.split()
    
    idx_list = []

    if sentiment == 'positive':
        for w in splited_text:
            score = sid.polarity_scores(w)['compound']
            score_list.append(score)
        if verbose: print('scores:', score_list)
        for scr in [x for x in set(heapq.nlargest(topk, score_list))]:
            if scr <= 0.0:
                continue
            idx_list.append(score_list.index(scr))

    elif sentiment == 'negative':
        for w in splited_text:
            score = sid.polarity_scores(w)['compound']
            score_list.append(score)
        if verbose: print('scores:', score_list)
        for scr in [x for x in set(heapq.nsmallest(topk, score_list))]:
            if scr >= 0.0:
                continue
            idx_list.append(score_list.index(scr))
    
    if not idx_list:
        return ''
    
    start_idx = min(idx_list)
    end_idx = max(idx_list)
    selected_text = splited_text[start_idx:end_idx+1]
    
    if len(selected_text) < 2:
        return ''
    
    return ' '.join(selected_text)

# %% [markdown]
# ## nan 인 것 만 새로 라벨링 (11975 rows)

# %%
orig_data = train_data[train_data.selected_text == 'nan']

# %%
orig_data
# Out:
#            textID  sentiment         author  \
# 6      1956968487    sadness       ShansBee
# 7      1956968636      worry       mcsleazy
# 9      1956969172    sadness     Ingenue_Em
# 15     1956971077    sadness         Sim_34
# 22     1956972116    neutral          jansc
# ...           ...        ...            ...
# 39983  1753905073    neutral       ABZQuine
# 39990  1753918829    neutral        kdpaine
# 39993  1753918892    neutral     bushidosan
# 39994  1753918900  happiness   courtside101
# 39995  1753918954    neutral  showMe_Heaven
#
#                                                     text  \
# 6      I should be sleep, but im not! thinking about ...
# 7                   Hmmm. http://www.djhero.com/ is down
# 9                       I`m sorry  at least it`s Friday?
# 15         The storm is here and the electricity is gone
# 22     No Topic Maps talks at the Balisage Markup Con...
# ...                                                  ...
# 39983  not really just leaving flat now, on the looko...
# 39990  I think the lesson of the day is not to have l...
# 39993  haha, yeah. Twitter has many uses. For me it`s...
# 39994                      Succesfully following Tayla!!
# 39995                                                nan
#
#                                                 old_text       aux_id  \
# 6      I should be sleep, but im not! thinking about ...  p1000000001
# 7                   Hmmm. http://www.djhero.com/ is down   2dfbe0b7fb
# 9             @kelcouch I'm sorry  at least it's Friday?   6d846d7d50
# 15         The storm is here and the electricity is gone  p1000000002
# 22     No Topic Maps talks at the Balisage Markup Con...  p1000000003
# ...                                                  ...          ...
# 39983  @Astronick not really just leaving flat now, o...  p1000008982
# 39990  @shonali I think the lesson of the day is not ...  p1000008983
# 39993  @sendsome2me haha, yeah. Twitter has many uses...  p1000008984
# 39994                      Succesfully following Tayla!!   bd499c0bf7
# 39995                                   @JohnLloydTaylor  p1000008985
#
#       new_sentiment selected_text
# 6               NaN           nan
# 7          negative           nan
# 9          negative           nan
# 15              NaN           nan
# 22              NaN           nan
# ...             ...           ...
# 39983           NaN           nan
# 39990           NaN           nan
# 39993           NaN           nan
# 39994      positive           nan
# 39995       neutral           nan
#
# [11975 rows x 8 columns]

# %% [markdown]
# ## 일단 뉴트럴 제외하고!, 길이 2 이상인 긍/부정 답안만 포함 (1이 많이 포함되면 짧은 애들을 더 찾을까봐)

# %%
aug_data = []

empty_cnt = 0
for idx, text in enumerate(orig_data.text):
    row = orig_data.iloc[idx]
    
    text = re.sub('http[s]?://\S+', '', row.text)

    senti = row.sentiment
    senti = sent_map[senti]
    if senti == neu:
        #aug_data.append({
        #    'textID': row.textID,
        #    'text': row.text,
        #    'sentiment': senti,
        #    'selected_text': row.text,
        #})
        continue
    
    pseudo_label = ext_sent_word(text, senti)
    
    if pseudo_label != '':
        aug_data.append({
            'textID': row.textID,
            'text': text,
            'sentiment': senti,
            'selected_text': pseudo_label,
        })
    else:
        empty_cnt += 1
    
empty_cnt
# Out:
# 7006

# %%
len(aug_data)
# Out:
# 2223

# %%
textIDs = []
texts = []
sentiments = []
selected_texts = []

for data in aug_data:
    textIDs.append(data['textID'])
    texts.append(data['text'])
    sentiments.append(data['sentiment'])
    selected_texts.append(data['selected_text'])

# %%
df = pd.DataFrame.from_dict({
    'textID': textIDs,
    'text': texts,
    'sentiment': sentiments,
    'selected_text': selected_texts
})

# %%
df
# Out:
#           textID                                               text sentiment  \
# 0     1956977187  <3 your gonna be the first  twitter ;) cause y...  positive
# 1     1956982383  Aww  Onward and upwards now, yay! Still sad to...  negative
# 2     1956987950  .. I`m suppposed to be sleep. But i got some m...  negative
# 3     1956991673  i wanted to come to BZ this summer :/ not so s...  negative
# 4     1956996776        Is miserable  i feel like im gona cry  sux!  negative
# ...          ...                                                ...       ...
# 2218  1753886405  thanks for promoing the show for me in my abse...  positive
# 2219  1753902805  U think web design wld go down well at the Int...  positive
# 2220  1753903062  Haha! I`ll try that next time he`s up north!  ...  positive
# 2221  1753904142  LOL or maybe it`s the tooth fairy, takes `em t...  positive
# 2222  1753904502  Anyone knows a site like the Swedish site 'sl....  positive
#
#                                           selected_text
# 0     <3 your gonna be the first twitter ;) cause yo...
# 1                                          sad to leave
# 2                         stuck in my head 'your a jerk
# 3     :/ not so sure anymore... a teacher`s life in ...
# 4                     miserable i feel like im gona cry
# ...                                                 ...
# 2218  thanks for promoing the show for me in my abse...
# 2219  well at the International Brotherhood of Magic...
# 2220  Haha! I`ll try that next time he`s up north! T...
# 2221  LOL or maybe it`s the tooth fairy, takes `em t...
# 2222                                       great useful
#
# [2223 rows x 4 columns]

# %%
df.to_csv('./dataset/pseudo_senti_dict.csv', index=False)

# %%
df.sentiment.value_counts()
# Out:
# positive    1491
# negative     732
# Name: sentiment, dtype: int64
